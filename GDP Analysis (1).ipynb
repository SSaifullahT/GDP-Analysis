# %%
#importing 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Part 1A

# %%
#reading the csv file
df = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\data 1-a.csv")

#displaying the table 
df.head(12)
# Out:
#                     Items  Description Duration  Andhra Pradesh   \
# 0   GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1   GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2   GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3   GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4   GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5   GSDP - CURRENT PRICES (` in Crore)  2016-17        699307.00
# 6        (% Growth over previous year)  2012-13             8.43
# 7        (% Growth over previous year)  2013-14            12.85
# 8        (% Growth over previous year)  2014-15            13.40
# 9        (% Growth over previous year)  2015-16            15.85
# 10       (% Growth over previous year)  2016-17            14.65
#
#     Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa  \
# 0            11063.00  143175.00  247144.00     158074.00  42367.00
# ...

# %%
# displaying the columns
df.columns
# Out:
# Index(['Items  Description', 'Duration', 'Andhra Pradesh ',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal1', 'Andaman & Nicobar Islands',
#        'Chandigarh', 'Delhi', 'Puducherry', 'All_India GDP'],
#       dtype='object')

# %%
#removing the row (% Growth over the previous year) and GSDP - CURRENT PRICES (` in Crore) for the year 2016-17.
df = df.drop(df[(df['Items  Description'] == '(% Growth over previous year)') & (df['Duration'] == "2016-17")].index)
df = df.drop(df[(df['Items  Description'] ==  'GSDP - CURRENT PRICES (` in Crore)') & (df['Duration'] == "2016-17")].index)

#displaying the table
df.head(11)
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
#seeing the null values
df.isnull().sum()
# Out:
# Items  Description           0
# Duration                     0
# Andhra Pradesh               0
# Arunachal Pradesh            0
# Assam                        0
# Bihar                        0
# Chhattisgarh                 0
# Goa                          0
# Gujarat                      0
# Haryana                      0
# Himachal Pradesh             2
# Jammu & Kashmir              0
# Jharkhand                    0
# Karnataka                    0
# Kerala                       0
# Madhya Pradesh               0
# Maharashtra                  2
# Manipur                      2
# Meghalaya                    0
# Mizoram                      2
# Nagaland                     2
# Odisha                       0
# Punjab                       2
# Rajasthan                    2
# Sikkim                       0
# Tamil Nadu                   0
# Telangana                    0
# Tripura                      2
# Uttar Pradesh                0
# Uttarakhand                  0
# ...

# %%
#removing the column whose all values are null
df=df.drop("West Bengal1", axis = 1)

df
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
#dividing the dataframe into 2 dataframes from the row one with GSDP - CURRENT PRICES (` in Crore) and other with (% Growth over previous year)
df1 = df.iloc[:5,:]
df2 = df.iloc[5:,:]

# Seeing 1st dataframe
df1.head(10)
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12         379402.0
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13         411404.0
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14         464272.0
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15         526468.0
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 0            11063.0  143175.0  247144.0      158074.0  42367.0  615606.0
# 1            12547.0  156864.0  282368.0      177511.0  38120.0  724495.0
# 2            14602.0  177745.0  317101.0      206690.0  35921.0  807623.0
# 3            16761.0  198098.0  373920.0      234982.0  40633.0  895027.0
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana      ...        Tamil Nadu  Telangana  Tripura  Uttar Pradesh  \
# ...

# %%
#seeing 2nd dataframe
df2.head(10)
# Out:
#               Items  Description Duration  Andhra Pradesh   Arunachal Pradesh  \
# 6  (% Growth over previous year)  2012-13             8.43              13.41
# 7  (% Growth over previous year)  2013-14            12.85              16.38
# 8  (% Growth over previous year)  2014-15            13.40              14.79
# 9  (% Growth over previous year)  2015-16            15.85              12.07
#
#    Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana      ...        \
# 6   9.56  14.25         12.30 -10.02    17.69    16.63      ...
# 7  13.31  12.30         16.44  -5.77    11.47    15.45      ...
# 8  11.45  17.92         13.69  13.12    10.82     9.18      ...
# 9  13.19  10.59         10.98  10.75    11.09    10.91      ...
#
#    Tamil Nadu  Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# 6       13.84      11.70    12.78          13.65        14.12
# 7       13.51      12.63    18.14          14.73        13.64
# ...

# %%
#seeing the how many null values are there and in which columns
df1.isnull().sum()
# Out:
# Items  Description           0
# Duration                     0
# Andhra Pradesh               0
# Arunachal Pradesh            0
# Assam                        0
# Bihar                        0
# Chhattisgarh                 0
# Goa                          0
# Gujarat                      0
# Haryana                      0
# Himachal Pradesh             1
# Jammu & Kashmir              0
# Jharkhand                    0
# Karnataka                    0
# Kerala                       0
# Madhya Pradesh               0
# Maharashtra                  1
# Manipur                      1
# Meghalaya                    0
# Mizoram                      1
# Nagaland                     1
# Odisha                       0
# Punjab                       1
# Rajasthan                    1
# Sikkim                       0
# Tamil Nadu                   0
# Telangana                    0
# Tripura                      1
# Uttar Pradesh                0
# Uttarakhand                  0
# ...

# %%
#Replacing the null values with the mean values of that column in both the data frame

# %%
df1.loc[np.isnan(df1['Himachal Pradesh']),['Himachal Pradesh']]=df1['Himachal Pradesh'].mean()
df2.loc[np.isnan(df2['Himachal Pradesh']),['Himachal Pradesh']]=df2['Himachal Pradesh'].mean()

# %%
df1.loc[np.isnan(df1['Maharashtra']),['Maharashtra']]=df1['Maharashtra'].mean()
df2.loc[np.isnan(df2['Maharashtra']),['Maharashtra']]=df2['Maharashtra'].mean()

# %%
df1.loc[np.isnan(df1['Manipur']),['Manipur']]=df1['Manipur'].mean()
df2.loc[np.isnan(df2['Manipur']),['Manipur']]=df2['Manipur'].mean()

# %%
df1.loc[np.isnan(df1['Mizoram']),['Mizoram']]=df1['Mizoram'].mean()
df2.loc[np.isnan(df2['Mizoram']),['Mizoram']]=df2['Mizoram'].mean()

# %%
df1.loc[np.isnan(df1['Nagaland']),['Nagaland']]=df1['Nagaland'].mean()
df2.loc[np.isnan(df2['Nagaland']),['Nagaland']]=df2['Nagaland'].mean()

# %%
df1.loc[np.isnan(df1['Punjab']),['Punjab']]=df1['Punjab'].mean()
df2.loc[np.isnan(df2['Punjab']),['Punjab']]=df2['Punjab'].mean()

# %%
df1.loc[np.isnan(df1['Rajasthan']),['Rajasthan']]=df1['Rajasthan'].mean()
df2.loc[np.isnan(df2['Rajasthan']),['Rajasthan']]=df2['Rajasthan'].mean()

# %%
df1.loc[np.isnan(df1['Tripura']),['Tripura']]=df1['Tripura'].mean()
df2.loc[np.isnan(df2['Tripura']),['Tripura']]=df2['Tripura'].mean()

# %%
df1.loc[np.isnan(df1['Andaman & Nicobar Islands']),['Andaman & Nicobar Islands']]=df1['Andaman & Nicobar Islands'].mean()
df2.loc[np.isnan(df2['Andaman & Nicobar Islands']),['Andaman & Nicobar Islands']]=df2['Andaman & Nicobar Islands'].mean()

# %%
df1.head()
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12         379402.0
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13         411404.0
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14         464272.0
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15         526468.0
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 0            11063.0  143175.0  247144.0      158074.0  42367.0  615606.0
# 1            12547.0  156864.0  282368.0      177511.0  38120.0  724495.0
# 2            14602.0  177745.0  317101.0      206690.0  35921.0  807623.0
# 3            16761.0  198098.0  373920.0      234982.0  40633.0  895027.0
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana      ...        Tamil Nadu  Telangana   Tripura  Uttar Pradesh  \
# ...

# %%
#conactinating top-bottom both dataframe after the null values havebean dealt with
df = pd.concat([df1,df2])

df.head(10)
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
df2.head()
# Out:
#               Items  Description Duration  Andhra Pradesh   Arunachal Pradesh  \
# 6  (% Growth over previous year)  2012-13             8.43              13.41
# 7  (% Growth over previous year)  2013-14            12.85              16.38
# 8  (% Growth over previous year)  2014-15            13.40              14.79
# 9  (% Growth over previous year)  2015-16            15.85              12.07
#
#    Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana      ...        \
# 6   9.56  14.25         12.30 -10.02    17.69    16.63      ...
# 7  13.31  12.30         16.44  -5.77    11.47    15.45      ...
# 8  11.45  17.92         13.69  13.12    10.82     9.18      ...
# 9  13.19  10.59         10.98  10.75    11.09    10.91      ...
#
#    Tamil Nadu  Telangana    Tripura  Uttar Pradesh  Uttarakhand  \
# 6       13.84      11.70  12.780000          13.65        14.12
# 7       13.51      12.63  18.140000          14.73        13.64
# ...

# %%
#resetting the index of the dataframe
df2 = df2.reset_index(drop = True)

#seeing the dataframe
df2.head()
# Out:
#               Items  Description Duration  Andhra Pradesh   Arunachal Pradesh  \
# 0  (% Growth over previous year)  2012-13             8.43              13.41
# 1  (% Growth over previous year)  2013-14            12.85              16.38
# 2  (% Growth over previous year)  2014-15            13.40              14.79
# 3  (% Growth over previous year)  2015-16            15.85              12.07
#
#    Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana      ...        \
# 0   9.56  14.25         12.30 -10.02    17.69    16.63      ...
# 1  13.31  12.30         16.44  -5.77    11.47    15.45      ...
# 2  11.45  17.92         13.69  13.12    10.82     9.18      ...
# 3  13.19  10.59         10.98  10.75    11.09    10.91      ...
#
#    Tamil Nadu  Telangana    Tripura  Uttar Pradesh  Uttarakhand  \
# 0       13.84      11.70  12.780000          13.65        14.12
# 1       13.51      12.63  18.140000          14.73        13.64
# ...

# %%
#removing the first row of the dataframe
df2 = df2.iloc[1:,:]

df2.head()
# Out:
#               Items  Description Duration  Andhra Pradesh   Arunachal Pradesh  \
# 1  (% Growth over previous year)  2013-14            12.85              16.38
# 2  (% Growth over previous year)  2014-15            13.40              14.79
# 3  (% Growth over previous year)  2015-16            15.85              12.07
#
#    Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana      ...        \
# 1  13.31  12.30         16.44  -5.77    11.47    15.45      ...
# 2  11.45  17.92         13.69  13.12    10.82     9.18      ...
# 3  13.19  10.59         10.98  10.75    11.09    10.91      ...
#
#    Tamil Nadu  Telangana    Tripura  Uttar Pradesh  Uttarakhand  \
# 1       13.51      12.63  18.140000          14.73        13.64
# 2       12.51      13.05  15.920000          10.51         8.12
# 3       10.99      12.61  15.613333          10.58        13.65
#
#    Andaman & Nicobar Islands  Chandigarh  Delhi  Puducherry  All_India GDP
# ...

# %%
#again resetting the index
df2 = df2.reset_index(drop = True)

df2.head()
# Out:
#               Items  Description Duration  Andhra Pradesh   Arunachal Pradesh  \
# 0  (% Growth over previous year)  2013-14            12.85              16.38
# 1  (% Growth over previous year)  2014-15            13.40              14.79
# 2  (% Growth over previous year)  2015-16            15.85              12.07
#
#    Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana      ...        \
# 0  13.31  12.30         16.44  -5.77    11.47    15.45      ...
# 1  11.45  17.92         13.69  13.12    10.82     9.18      ...
# 2  13.19  10.59         10.98  10.75    11.09    10.91      ...
#
#    Tamil Nadu  Telangana    Tripura  Uttar Pradesh  Uttarakhand  \
# 0       13.51      12.63  18.140000          14.73        13.64
# 1       12.51      13.05  15.920000          10.51         8.12
# 2       10.99      12.61  15.613333          10.58        13.65
#
#    Andaman & Nicobar Islands  Chandigarh  Delhi  Puducherry  All_India GDP
# ...

# %%
#setting the index to the duration column
df2 =df2.set_index('Duration')
df2.head()
# Out:
#                      Items  Description  Andhra Pradesh   Arunachal Pradesh  \
# Duration
# 2013-14   (% Growth over previous year)            12.85              16.38
# 2014-15   (% Growth over previous year)            13.40              14.79
# 2015-16   (% Growth over previous year)            15.85              12.07
#
#           Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana  \
# Duration
# 2013-14   13.31  12.30         16.44  -5.77    11.47    15.45
# 2014-15   11.45  17.92         13.69  13.12    10.82     9.18
# 2015-16   13.19  10.59         10.98  10.75    11.09    10.91
#
#           Himachal Pradesh      ...        Tamil Nadu  Telangana    Tripura  \
# Duration                        ...
# 2013-14          14.420000      ...             13.51      12.63  18.140000
# 2014-15          10.140000      ...             12.51      13.05  15.920000
# 2015-16          12.816667      ...             10.99      12.61  15.613333
#
# ...

# %%
#removing the column Items Description
df2 = df2.drop('Items  Description',axis = 1)

df2.head()
# Out:
#           Andhra Pradesh   Arunachal Pradesh  Assam  Bihar  Chhattisgarh  \
# Duration
# 2013-14             12.85              16.38  13.31  12.30         16.44
# 2014-15             13.40              14.79  11.45  17.92         13.69
# 2015-16             15.85              12.07  13.19  10.59         10.98
#
#             Goa  Gujarat  Haryana  Himachal Pradesh  Jammu & Kashmir  \
# Duration
# 2013-14   -5.77    11.47    15.45         14.420000            10.09
# 2014-15   13.12    10.82     9.18         10.140000             4.70
# 2015-16   10.75    11.09    10.91         12.816667            17.91
#
#               ...        Tamil Nadu  Telangana    Tripura  Uttar Pradesh  \
# Duration      ...
# 2013-14       ...             13.51      12.63  18.140000          14.73
# 2014-15       ...             12.51      13.05  15.920000          10.51
# 2015-16       ...             10.99      12.61  15.613333          10.58
#
# ...

# %%
#Transposing the dataframe i.e inter-changing rows with columns
df2 = df2.T

#Seeing the dataframe
df2
# Out:
# Duration                   2013-14  2014-15    2015-16
# Andhra Pradesh               12.85    13.40  15.850000
# Arunachal Pradesh            16.38    14.79  12.070000
# Assam                        13.31    11.45  13.190000
# Bihar                        12.30    17.92  10.590000
# Chhattisgarh                 16.44    13.69  10.980000
# Goa                          -5.77    13.12  10.750000
# Gujarat                      11.47    10.82  11.090000
# Haryana                      15.45     9.18  10.910000
# Himachal Pradesh             14.42    10.14  12.816667
# Jammu & Kashmir              10.09     4.70  17.910000
# Jharkhand                     7.92    15.14  11.440000
# Karnataka                    18.24    12.70  11.420000
# Kerala                       12.79    13.11  11.850000
# Madhya Pradesh               14.91    10.11  12.860000
# Maharashtra                  13.74     8.78  12.103333
# Manipur                      17.83    11.39  11.890000
# ...

# %%
#All india GDP
df.loc['All_India GDP']

# %%
#Dropping the all india GDP row 
df2 = df2.drop("All_India GDP")
df2
# Out:
# Duration                   2013-14  2014-15    2015-16       Mean
# Goa                          -5.77    13.12  10.750000   6.033333
# Meghalaya                     4.87     6.41   9.580000   6.953333
# Odisha                       12.95    10.37   6.190000   9.836667
# Sikkim                       12.35     9.72   9.390000  10.486667
# Jammu & Kashmir              10.09     4.70  17.910000  10.900000
# Gujarat                      11.47    10.82  11.090000  11.126667
# Punjab                       12.42     9.95  11.346667  11.238889
# Jharkhand                     7.92    15.14  11.440000  11.500000
# Rajasthan                    11.27    11.37  11.940000  11.526667
# Maharashtra                  13.74     8.78  12.103333  11.541111
# Uttarakhand                  13.64     8.12  13.650000  11.803333
# Haryana                      15.45     9.18  10.910000  11.846667
# Uttar Pradesh                14.73    10.51  10.580000  11.940000
# ...

# %%
#Calculating and creating a new column of mean values
df2['Mean'] = df2.mean(axis = 1)

#Displaying the dataframe
df2
# Out:
# Duration                   2013-14  2014-15    2015-16       Mean
# Goa                          -5.77    13.12  10.750000   6.033333
# Meghalaya                     4.87     6.41   9.580000   6.953333
# Odisha                       12.95    10.37   6.190000   9.836667
# Sikkim                       12.35     9.72   9.390000  10.486667
# Jammu & Kashmir              10.09     4.70  17.910000  10.900000
# Gujarat                      11.47    10.82  11.090000  11.126667
# Punjab                       12.42     9.95  11.346667  11.238889
# Jharkhand                     7.92    15.14  11.440000  11.500000
# Rajasthan                    11.27    11.37  11.940000  11.526667
# Maharashtra                  13.74     8.78  12.103333  11.541111
# Uttarakhand                  13.64     8.12  13.650000  11.803333
# Haryana                      15.45     9.18  10.910000  11.846667
# Uttar Pradesh                14.73    10.51  10.580000  11.940000
# ...

# %%
#Sorting the dataframe according to the Mean value
df2 = df2.sort_values(['Mean'])

# %%
#Plotting the bargraph of mean values of various states
plt.figure(num=None,figsize=(12,12),dpi=80,facecolor='w',edgecolor='k')
sns.barplot(x=df2['Mean'],y=df2.index,data = df2)
plt.title('% Growth over Previous Year')
plt.show()

# %%
# Displaying the mean values of %Growth of various states
df2['Mean']
# Out:
# Goa                           6.033333
# Meghalaya                     6.953333
# Odisha                        9.836667
# Sikkim                       10.486667
# Jammu & Kashmir              10.900000
# Gujarat                      11.126667
# Punjab                       11.238889
# Jharkhand                    11.500000
# Rajasthan                    11.526667
# Maharashtra                  11.541111
# Uttarakhand                  11.803333
# Haryana                      11.846667
# Uttar Pradesh                11.940000
# Chandigarh                   11.960000
# Puducherry                   12.053333
# Delhi                        12.160000
# Tamil Nadu                   12.336667
# Himachal Pradesh             12.458889
# Kerala                       12.583333
# Madhya Pradesh               12.626667
# Assam                        12.650000
# Telangana                    12.763333
# Andaman & Nicobar Islands    13.490000
# Bihar                        13.603333
# ...

# %% [markdown]
# - States that are struggling - Goa, Meghalaya and Odisa
# - States that are constantly growing - Mizoram, Ttripura, Nagaland
# - National average of growth is 11.2
# - My home state (Uttar Pradesh) growth rate is 0.7 more than the National average of growth

# %%
#Desplaying the GDP of states DataFrame
df1
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12         379402.0
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13         411404.0
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14         464272.0
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15         526468.0
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 0            11063.0  143175.0  247144.0      158074.0  42367.0  615606.0
# 1            12547.0  156864.0  282368.0      177511.0  38120.0  724495.0
# 2            14602.0  177745.0  317101.0      206690.0  35921.0  807623.0
# 3            16761.0  198098.0  373920.0      234982.0  40633.0  895027.0
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana      ...        Tamil Nadu  Telangana   Tripura  Uttar Pradesh  \
# ...

# %%
# Dropping all the row except the 2015-16 duration
df1 = df1.iloc[4:,:]
df1
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana      ...        Tamil Nadu  Telangana   Tripura  Uttar Pradesh  \
# 4  485184.0      ...         1212668.0   575631.0  24032.75      1153795.0
#
#    Uttarakhand  Andaman & Nicobar Islands  Chandigarh     Delhi  Puducherry  \
# 4     184091.0                     4820.0     30304.0  551963.0     26533.0
#
#    All_India GDP
# 4     13675331.0
#
# [1 rows x 35 columns]

# %%
df1 = df1.reset_index(drop= True)
df1
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 0            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana      ...        Tamil Nadu  Telangana   Tripura  Uttar Pradesh  \
# 0  485184.0      ...         1212668.0   575631.0  24032.75      1153795.0
#
#    Uttarakhand  Andaman & Nicobar Islands  Chandigarh     Delhi  Puducherry  \
# 0     184091.0                     4820.0     30304.0  551963.0     26533.0
#
#    All_India GDP
# 0     13675331.0
#
# [1 rows x 35 columns]

# %%
df1
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 0            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana      ...        Tamil Nadu  Telangana   Tripura  Uttar Pradesh  \
# 0  485184.0      ...         1212668.0   575631.0  24032.75      1153795.0
#
#    Uttarakhand  Andaman & Nicobar Islands  Chandigarh     Delhi  Puducherry  \
# 0     184091.0                     4820.0     30304.0  551963.0     26533.0
#
#    All_India GDP
# 0     13675331.0
#
# [1 rows x 35 columns]

# %%
# Changing the index to the Duration
df1 = df1.set_index('Duration')
df1
# Out:
#                           Items  Description  Andhra Pradesh   \
# Duration
# 2015-16   GSDP - CURRENT PRICES (` in Crore)         609934.0
#
#           Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa  \
# Duration
# 2015-16             18784.0  224234.0  413503.0      260776.0  45002.0
#
#            Gujarat   Haryana  Himachal Pradesh      ...        Tamil Nadu  \
# Duration                                            ...
# 2015-16   994316.0  485184.0          88668.25      ...         1212668.0
#
#           Telangana   Tripura  Uttar Pradesh  Uttarakhand  \
# Duration
# 2015-16    575631.0  24032.75      1153795.0     184091.0
#
#           Andaman & Nicobar Islands  Chandigarh     Delhi  Puducherry  \
# Duration
# 2015-16                      4820.0     30304.0  551963.0     26533.0
#
#           All_India GDP
# Duration
# 2015-16      13675331.0
#
# [1 rows x 34 columns]

# %%
#Droppring the column Items Description
df1 = df1.drop('Items  Description',axis =1)

# %%
#Desplaying the dataframe
df1
# Out:
#           Andhra Pradesh   Arunachal Pradesh     Assam     Bihar  \
# Duration
# 2015-16          609934.0            18784.0  224234.0  413503.0
#
#           Chhattisgarh      Goa   Gujarat   Haryana  Himachal Pradesh  \
# Duration
# 2015-16       260776.0  45002.0  994316.0  485184.0          88668.25
#
#           Jammu & Kashmir      ...        Tamil Nadu  Telangana   Tripura  \
# Duration                       ...
# 2015-16          118387.0      ...         1212668.0   575631.0  24032.75
#
#           Uttar Pradesh  Uttarakhand  Andaman & Nicobar Islands  Chandigarh  \
# Duration
# 2015-16       1153795.0     184091.0                     4820.0     30304.0
#
#              Delhi  Puducherry  All_India GDP
# Duration
# 2015-16   551963.0     26533.0     13675331.0
#
# [1 rows x 33 columns]

# %%
#Transposing the dataframe
df1 = df1.T
df1
# Out:
# Duration                       2015-16
# Andhra Pradesh               609934.00
# Arunachal Pradesh             18784.00
# Assam                        224234.00
# Bihar                        413503.00
# Chhattisgarh                 260776.00
# Goa                           45002.00
# Gujarat                      994316.00
# Haryana                      485184.00
# Himachal Pradesh              88668.25
# Jammu & Kashmir              118387.00
# Jharkhand                    241955.00
# Karnataka                   1027068.00
# Kerala                       588337.00
# Madhya Pradesh               543975.00
# Maharashtra                 1540265.25
# Manipur                       15226.00
# Meghalaya                     26745.00
# Mizoram                        9368.25
# Nagaland                      15121.00
# Odisha                       341887.00
# Punjab                       316771.75
# Rajasthan                    523091.00
# Sikkim                        16637.00
# ...

# %%
#Renaming the column
df1 = df1.rename(columns = {"2015-16" : "GDP of States in 2015-16"})
df1
# Out:
# Duration                   GDP of States in 2015-16
# Andhra Pradesh                            609934.00
# Arunachal Pradesh                          18784.00
# Assam                                     224234.00
# Bihar                                     413503.00
# Chhattisgarh                              260776.00
# Goa                                        45002.00
# Gujarat                                   994316.00
# Haryana                                   485184.00
# Himachal Pradesh                           88668.25
# Jammu & Kashmir                           118387.00
# Jharkhand                                 241955.00
# Karnataka                                1027068.00
# Kerala                                    588337.00
# Madhya Pradesh                            543975.00
# Maharashtra                              1540265.25
# Manipur                                    15226.00
# Meghalaya                                  26745.00
# ...

# %%
#Sorting the rows on the basis of the GDP value
df1 = df1.sort_values("GDP of States in 2015-16")
df1
# Out:
# Duration                   GDP of States in 2015-16
# Andaman & Nicobar Islands                   4820.00
# Mizoram                                     9368.25
# Nagaland                                   15121.00
# Manipur                                    15226.00
# Sikkim                                     16637.00
# Arunachal Pradesh                          18784.00
# Tripura                                    24032.75
# Puducherry                                 26533.00
# Meghalaya                                  26745.00
# Chandigarh                                 30304.00
# Goa                                        45002.00
# Himachal Pradesh                           88668.25
# Jammu & Kashmir                           118387.00
# Uttarakhand                               184091.00
# Assam                                     224234.00
# Jharkhand                                 241955.00
# Chhattisgarh                              260776.00
# ...

# %%
df1 = df1.drop('All_India GDP')
df1
# Out:
# Duration                   GDP of States in 2015-16
# Andaman & Nicobar Islands                   4820.00
# Mizoram                                     9368.25
# Nagaland                                   15121.00
# Manipur                                    15226.00
# Sikkim                                     16637.00
# Arunachal Pradesh                          18784.00
# Tripura                                    24032.75
# Puducherry                                 26533.00
# Meghalaya                                  26745.00
# Chandigarh                                 30304.00
# Goa                                        45002.00
# Himachal Pradesh                           88668.25
# Jammu & Kashmir                           118387.00
# Uttarakhand                               184091.00
# Assam                                     224234.00
# Jharkhand                                 241955.00
# Chhattisgarh                              260776.00
# ...

# %%
#Plotting the bar graph of the states GDP 
plt.figure(num=None,figsize=(12,12),dpi=80,facecolor='w',edgecolor='k')
sns.barplot(x=df1['GDP of States in 2015-16'],y=df1.index,data = df1)
plt.title('GDP of various states in year 2015-16')
plt.show()

# %% [markdown]
# - Top 5 states - Maharashtra, Tamil Nadu, Uttar Pradesh, Karnataka, Gujrat
# - Bottom 5 States - Andaman & Nicobar Islands, Mizoram, Nagaland, Minipur, Sikkim

# %% [markdown]
# # Part 1B

# %%
#Reading CSV file 
ap = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Andhra_Pradesh-GSVA_cur_2016-17.csv")
ap
# Out:
#     S.No.                                               Item   2011-12  \
# 0       1                  Agriculture, forestry and fishing   9400805
# 1     1.1                                              Crops   5204052
# 2     1.2                                          Livestock   2758776
# 3     1.3                               Forestry and logging    250314
# 4     1.4                            Fishing and aquaculture   1187663
# 5       2                               Mining and quarrying   1416194
# 6   Total                                            Primary  10816999
# 7       3                                      Manufacturing   5070622
# 8       4  Electricity, gas, water supply & other utility...   1076517
# 9       5                                       Construction   3702645
# 10  Total                                          Secondary   9849784
# 11      6              Trade, repair, hotels and restaurants   2673600
# ...

# %%
#Removing columns except 2014-15 data
ap = ap.drop("2011-12", axis = 1)
ap = ap.drop("2012-13", axis = 1)
ap = ap.drop("2013-14", axis = 1)
ap = ap.drop("2015-16", axis = 1)
ap = ap.drop("2016-17", axis = 1)
ap
# Out:
#     S.No.                                               Item   2014-15
# 0       1                  Agriculture, forestry and fishing  14819416
# 1     1.1                                              Crops   7893514
# 2     1.2                                          Livestock   4309078
# 3     1.3                               Forestry and logging    346160
# 4     1.4                            Fishing and aquaculture   2270664
# 5       2                               Mining and quarrying   1484300
# 6   Total                                            Primary  16303716
# 7       3                                      Manufacturing   4672266
# 8       4  Electricity, gas, water supply & other utility...   1151729
# 9       5                                       Construction   4664889
# 10  Total                                          Secondary  10488884
# 11      6              Trade, repair, hotels and restaurants   4233400
# ...

# %%
#Adding the state column
ap = ap.assign(State='Andhra_Pradesh')[['State'] + ap.columns.tolist()]
#Dropping the S.no column
ap = ap.drop('S.No.',axis = 1)
ap = ap.reset_index(drop=True)
ap
# Out:
#              State                                               Item  \
# 0   Andhra_Pradesh                  Agriculture, forestry and fishing
# 1   Andhra_Pradesh                                              Crops
# 2   Andhra_Pradesh                                          Livestock
# 3   Andhra_Pradesh                               Forestry and logging
# 4   Andhra_Pradesh                            Fishing and aquaculture
# 5   Andhra_Pradesh                               Mining and quarrying
# 6   Andhra_Pradesh                                            Primary
# 7   Andhra_Pradesh                                      Manufacturing
# 8   Andhra_Pradesh  Electricity, gas, water supply & other utility...
# 9   Andhra_Pradesh                                       Construction
# 10  Andhra_Pradesh                                          Secondary
# 11  Andhra_Pradesh              Trade, repair, hotels and restaurants
# ...

# %%
arp = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Arunachal_Pradesh-GSVA_cur_2015-16.csv")
arp
# Out:
#     S.No.                                               Item  2011-12  \
# 0       1                  Agriculture, forestry and fishing   455505
# 1     1.1                                              Crops   255815
# 2     1.2                                          Livestock    29657
# 3     1.3                               Forestry and logging   165510
# 4     1.4                            Fishing and aquaculture     4523
# 5       2                               Mining and quarrying    23022
# 6   Total                                            Primary   478527
# 7       3                                      Manufacturing    12900
# 8       4  Electricity, gas, water supply & other utility...    69131
# 9       5                                       Construction   104529
# 10  Total                                          Secondary   186560
# 11      6              Trade, repair, hotels and restaurants    59892
# ...

# %%
arp = arp.drop("2011-12", axis = 1)
arp = arp.drop("2012-13", axis = 1)
arp = arp.drop("2013-14", axis = 1)
arp = arp.drop("2015-16", axis = 1)
arp
# Out:
#     S.No.                                               Item  2014-15
# 0       1                  Agriculture, forestry and fishing   686117
# 1     1.1                                              Crops   415520
# 2     1.2                                          Livestock    38387
# 3     1.3                               Forestry and logging   224017
# 4     1.4                            Fishing and aquaculture     8193
# 5       2                               Mining and quarrying    30842
# 6   Total                                            Primary   716959
# 7       3                                      Manufacturing    26120
# 8       4  Electricity, gas, water supply & other utility...   113527
# 9       5                                       Construction   147842
# 10  Total                                          Secondary   287489
# 11      6              Trade, repair, hotels and restaurants    60421
# ...

# %%
arp = arp.assign(State='Arunachal_Pradesh')[['State'] + arp.columns.tolist()]
arp = arp.drop('S.No.',axis = 1)
arp = arp.reset_index(drop=True)
arp
# Out:
#                 State                                               Item  \
# 0   Arunachal_Pradesh                  Agriculture, forestry and fishing
# 1   Arunachal_Pradesh                                              Crops
# 2   Arunachal_Pradesh                                          Livestock
# 3   Arunachal_Pradesh                               Forestry and logging
# 4   Arunachal_Pradesh                            Fishing and aquaculture
# 5   Arunachal_Pradesh                               Mining and quarrying
# 6   Arunachal_Pradesh                                            Primary
# 7   Arunachal_Pradesh                                      Manufacturing
# 8   Arunachal_Pradesh  Electricity, gas, water supply & other utility...
# 9   Arunachal_Pradesh                                       Construction
# 10  Arunachal_Pradesh                                          Secondary
# 11  Arunachal_Pradesh              Trade, repair, hotels and restaurants
# ...

# %%
asa = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Assam-GSVA_cur_2015-16.csv")
asa
# Out:
#     S.No.                                               Item   2011-12  \
# 0       1                  Agriculture, forestry and fishing   2848113
# 1     1.1                                              Crops   2061487
# 2     1.2                                          Livestock    159289
# 3     1.3                               Forestry and logging    231388
# 4     1.4                            Fishing and aquaculture    395949
# 5       2                               Mining and quarrying   1464989
# 6   Total                                            Primary   4313102
# 7       3                                      Manufacturing   1540255
# 8       4  Electricity, gas, water supply & other utility...    191883
# 9       5                                       Construction   1188747
# 10  Total                                          Secondary   2920885
# 11      6              Trade, repair, hotels and restaurants   2045676
# ...

# %%
asa = asa.drop("2011-12", axis = 1)
asa = asa.drop("2012-13", axis = 1)
asa = asa.drop("2013-14", axis = 1)
asa = asa.drop("2015-16", axis = 1)
asa
# Out:
#     S.No.                                               Item   2014-15
# 0       1                  Agriculture, forestry and fishing   3855548
# 1     1.1                                              Crops   2890544
# 2     1.2                                          Livestock    173478
# 3     1.3                               Forestry and logging    261987
# 4     1.4                            Fishing and aquaculture    529539
# 5       2                               Mining and quarrying   1471149
# 6   Total                                            Primary   5326697
# 7       3                                      Manufacturing   2002936
# 8       4  Electricity, gas, water supply & other utility...    296587
# 9       5                                       Construction   1733568
# 10  Total                                          Secondary   4033091
# 11      6              Trade, repair, hotels and restaurants   2987155
# ...

# %%
asa = asa.assign(State='Assam')[['State'] + asa.columns.tolist()]
asa = asa.drop('S.No.',axis = 1)
asa = asa.reset_index(drop=True)
asa
# Out:
#     State                                               Item   2014-15
# 0   Assam                  Agriculture, forestry and fishing   3855548
# 1   Assam                                              Crops   2890544
# 2   Assam                                          Livestock    173478
# 3   Assam                               Forestry and logging    261987
# 4   Assam                            Fishing and aquaculture    529539
# 5   Assam                               Mining and quarrying   1471149
# 6   Assam                                            Primary   5326697
# 7   Assam                                      Manufacturing   2002936
# 8   Assam  Electricity, gas, water supply & other utility...    296587
# 9   Assam                                       Construction   1733568
# 10  Assam                                          Secondary   4033091
# 11  Assam              Trade, repair, hotels and restaurants   2987155
# ...

# %%
bi = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Bihar-GSVA_cur_2015-16.csv")
bi
# Out:
#     S.No.                                               Item   2011-12  \
# 0       1                  Agriculture, forestry and fishing   6206655
# 1     1.1                                              Crops   4260778
# 2     1.2                                          Livestock   1202821
# 3     1.3                               Forestry and logging    418682
# 4     1.4                            Fishing and aquaculture    324374
# 5       2                               Mining and quarrying     19858
# 6   Total                                            Primary   6226513
# 7       3                                      Manufacturing   1466570
# 8       4  Electricity, gas, water supply & other utility...    365887
# 9       5                                       Construction   2701685
# 10  Total                                          Secondary   4534142
# 11      6              Trade, repair, hotels and restaurants   4390442
# ...

# %%
bi = bi.drop("2011-12", axis = 1)
bi = bi.drop("2012-13", axis = 1)
bi = bi.drop("2013-14", axis = 1)
bi = bi.drop("2015-16", axis = 1)
bi
# Out:
#     S.No.                                               Item   2014-15
# 0       1                  Agriculture, forestry and fishing   7951890
# 1     1.1                                              Crops   4688237
# 2     1.2                                          Livestock   2060296
# 3     1.3                               Forestry and logging    550132
# 4     1.4                            Fishing and aquaculture    653224
# 5       2                               Mining and quarrying     68107
# 6   Total                                            Primary   8019997
# 7       3                                      Manufacturing   2189965
# 8       4  Electricity, gas, water supply & other utility...    345168
# 9       5                                       Construction   3449763
# 10  Total                                          Secondary   5984896
# 11      6              Trade, repair, hotels and restaurants   7448373
# ...

# %%
bi = bi.assign(State='Bihar')[['State'] + bi.columns.tolist()]
bi = bi.drop('S.No.',axis = 1)
bi = bi.reset_index(drop=True)
bi
# Out:
#     State                                               Item   2014-15
# 0   Bihar                  Agriculture, forestry and fishing   7951890
# 1   Bihar                                              Crops   4688237
# 2   Bihar                                          Livestock   2060296
# 3   Bihar                               Forestry and logging    550132
# 4   Bihar                            Fishing and aquaculture    653224
# 5   Bihar                               Mining and quarrying     68107
# 6   Bihar                                            Primary   8019997
# 7   Bihar                                      Manufacturing   2189965
# 8   Bihar  Electricity, gas, water supply & other utility...    345168
# 9   Bihar                                       Construction   3449763
# 10  Bihar                                          Secondary   5984896
# 11  Bihar              Trade, repair, hotels and restaurants   7448373
# ...

# %%
ch = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Chhattisgarh-GSVA_cur_2016-17.csv")
ch
# Out:
#     S.No.                                               Item   2011-12  \
# 0       1                  Agriculture, forestry and fishing   2685950
# 1     1.1                                              Crops   1798258
# 2     1.2                                          Livestock    226704
# 3     1.3                               Forestry and logging    426205
# 4     1.4                            Fishing and aquaculture    234783
# 5       2                               Mining and quarrying   1970258
# 6   Total                                            Primary   4656208
# 7       3                                      Manufacturing   2435032
# 8       4  Electricity, gas, water supply & other utility...    709991
# 9       5                                       Construction   1901330
# 10  Total                                          Secondary   5046354
# 11      6              Trade, repair, hotels and restaurants    932617
# ...

# %%
ch = ch.drop("2011-12", axis = 1)
ch = ch.drop("2012-13", axis = 1)
ch = ch.drop("2013-14", axis = 1)
ch = ch.drop("2015-16", axis = 1)
ch = ch.drop("2016-17", axis = 1)
ch
# Out:
#     S.No.                                               Item   2014-15
# 0       1                  Agriculture, forestry and fishing   3948847
# 1     1.1                                              Crops   2613371
# 2     1.2                                          Livestock    352208
# 3     1.3                               Forestry and logging    597785
# 4     1.4                            Fishing and aquaculture    385483
# 5       2                               Mining and quarrying   2451970
# 6   Total                                            Primary   6400817
# 7       3                                      Manufacturing   4370593
# 8       4  Electricity, gas, water supply & other utility...   1198438
# 9       5                                       Construction   2669855
# 10  Total                                          Secondary   8238886
# 11      6              Trade, repair, hotels and restaurants   1535571
# ...

# %%
ch = ch.assign(State='Chattisgarh')[['State'] + ch.columns.tolist()]
ch = ch.drop('S.No.',axis = 1)
ch = ch.reset_index(drop=True)
ch
# Out:
#           State                                               Item   2014-15
# 0   Chattisgarh                  Agriculture, forestry and fishing   3948847
# 1   Chattisgarh                                              Crops   2613371
# 2   Chattisgarh                                          Livestock    352208
# 3   Chattisgarh                               Forestry and logging    597785
# 4   Chattisgarh                            Fishing and aquaculture    385483
# 5   Chattisgarh                               Mining and quarrying   2451970
# 6   Chattisgarh                                            Primary   6400817
# 7   Chattisgarh                                      Manufacturing   4370593
# 8   Chattisgarh  Electricity, gas, water supply & other utility...   1198438
# 9   Chattisgarh                                       Construction   2669855
# 10  Chattisgarh                                          Secondary   8238886
# ...

# %%
goa = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Goa-GSVA_cur_2015-16.csv")
goa
# Out:
#     S.No.                                               Item  2011-12  \
# 0       1                  Agriculture, forestry and fishing   204298
# 1     1.1                                              Crops   102417
# 2     1.2                                          Livestock    23530
# 3     1.3                               Forestry and logging    11797
# 4     1.4                            Fishing and aquaculture    66554
# 5       2                               Mining and quarrying   643618
# 6   Total                                            Primary   847915
# 7       3                                      Manufacturing  1629346
# 8       4  Electricity, gas, water supply & other utility...    95883
# 9       5                                       Construction   135801
# 10  Total                                          Secondary  1861030
# 11      6              Trade, repair, hotels and restaurants   259615
# ...

# %%
goa = goa.drop("2011-12", axis = 1)
goa = goa.drop("2012-13", axis = 1)
goa = goa.drop("2013-14", axis = 1)
goa = goa.drop("2015-16", axis = 1)
goa
# Out:
#     S.No.                                               Item  2014-15
# 0       1                  Agriculture, forestry and fishing   308507
# 1     1.1                                              Crops   140421
# 2     1.2                                          Livestock    30141
# 3     1.3                               Forestry and logging    15744
# 4     1.4                            Fishing and aquaculture   122201
# 5       2                               Mining and quarrying     3622
# 6   Total                                            Primary   312129
# 7       3                                      Manufacturing  1177608
# 8       4  Electricity, gas, water supply & other utility...   204110
# 9       5                                       Construction   165819
# 10  Total                                          Secondary  1547536
# 11      6              Trade, repair, hotels and restaurants   380927
# ...

# %%
goa = goa.assign(State='Goa')[['State'] + goa.columns.tolist()]
goa = goa.drop('S.No.',axis = 1)
goa = goa.reset_index(drop=True)
goa
# Out:
#    State                                               Item  2014-15
# 0    Goa                  Agriculture, forestry and fishing   308507
# 1    Goa                                              Crops   140421
# 2    Goa                                          Livestock    30141
# 3    Goa                               Forestry and logging    15744
# 4    Goa                            Fishing and aquaculture   122201
# 5    Goa                               Mining and quarrying     3622
# 6    Goa                                            Primary   312129
# 7    Goa                                      Manufacturing  1177608
# 8    Goa  Electricity, gas, water supply & other utility...   204110
# 9    Goa                                       Construction   165819
# 10   Goa                                          Secondary  1547536
# 11   Goa              Trade, repair, hotels and restaurants   380927
# 12   Goa                            Trade & repair services   343492
# ...

# %%
guj = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Gujarat-GSVA_cur_2015-16.csv")
guj
# Out:
#     S.No.                                               Item     2011-12  \
# 0       1                  Agriculture, forestry and fishing  10736422.0
# 1     1.1                                              Crops   7950972.0
# 2     1.2                                          Livestock   1850549.0
# 3     1.3                               Forestry and logging    611318.0
# 4     1.4                            Fishing and aquaculture    323584.0
# 5       2                               Mining and quarrying   1850611.0
# 6   Total                                            Primary  12587033.0
# 7       3                                      Manufacturing  15681931.0
# 8       4  Electricity, gas, water supply & other utility...   2190546.0
# 9       5                                       Construction   4469267.0
# 10  Total                                          Secondary  22341743.0
# 11      6              Trade, repair, hotels and restaurants   6646396.0
# ...

# %%
guj = guj.drop("2011-12", axis = 1)
guj = guj.drop("2012-13", axis = 1)
guj = guj.drop("2013-14", axis = 1)
guj = guj.drop("2015-16", axis = 1)
guj
# Out:
#     S.No.                                               Item      2014-15
# 0       1                  Agriculture, forestry and fishing  13769969.00
# 1     1.1                                              Crops   9671086.00
# 2     1.2                                          Livestock   2698910.00
# 3     1.3                               Forestry and logging    761616.00
# 4     1.4                            Fishing and aquaculture    638357.00
# 5       2                               Mining and quarrying   2117218.00
# 6   Total                                            Primary  15887187.00
# 7       3                                      Manufacturing  24087538.00
# 8       4  Electricity, gas, water supply & other utility...   3409983.00
# 9       5                                       Construction   5526017.00
# 10  Total                                          Secondary  33023538.00
# 11      6              Trade, repair, hotels and restaurants  10178713.00
# ...

# %%
guj.loc[np.isnan(guj['2014-15']),['2014-15']]=0
guj
# Out:
#     S.No.                                               Item      2014-15
# 0       1                  Agriculture, forestry and fishing  13769969.00
# 1     1.1                                              Crops   9671086.00
# 2     1.2                                          Livestock   2698910.00
# 3     1.3                               Forestry and logging    761616.00
# 4     1.4                            Fishing and aquaculture    638357.00
# 5       2                               Mining and quarrying   2117218.00
# 6   Total                                            Primary  15887187.00
# 7       3                                      Manufacturing  24087538.00
# 8       4  Electricity, gas, water supply & other utility...   3409983.00
# 9       5                                       Construction   5526017.00
# 10  Total                                          Secondary  33023538.00
# 11      6              Trade, repair, hotels and restaurants  10178713.00
# ...

# %%
guj = guj.assign(State='Gujrat')[['State'] + guj.columns.tolist()]
guj = guj.drop('S.No.',axis = 1)
guj = guj.reset_index(drop=True)
guj
# Out:
#      State                                               Item      2014-15
# 0   Gujrat                  Agriculture, forestry and fishing  13769969.00
# 1   Gujrat                                              Crops   9671086.00
# 2   Gujrat                                          Livestock   2698910.00
# 3   Gujrat                               Forestry and logging    761616.00
# 4   Gujrat                            Fishing and aquaculture    638357.00
# 5   Gujrat                               Mining and quarrying   2117218.00
# 6   Gujrat                                            Primary  15887187.00
# 7   Gujrat                                      Manufacturing  24087538.00
# 8   Gujrat  Electricity, gas, water supply & other utility...   3409983.00
# 9   Gujrat                                       Construction   5526017.00
# 10  Gujrat                                          Secondary  33023538.00
# ...

# %%
har = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Haryana-GSVA_cur_2016-17.csv")
har
# Out:
#     S.No.                                               Item     2011-12  \
# 0       1                  Agriculture, forestry and fishing   6453886.0
# 1     1.1                                              Crops   4088737.0
# 2     1.2                                          Livestock   1889817.0
# 3     1.3                               Forestry and logging    389490.0
# 4     1.4                            Fishing and aquaculture     85843.0
# 5       2                               Mining and quarrying     11882.0
# 6   Total                                            Primary   6465768.0
# 7       3                                      Manufacturing   5328609.0
# 8       4  Electricity, gas, water supply & other utility...    344604.0
# 9       5                                       Construction   2975966.0
# 10  Total                                          Secondary   8649179.0
# 11      6              Trade, repair, hotels and restaurants   3310742.0
# ...

# %%
har = har.drop("2011-12", axis = 1)
har = har.drop("2012-13", axis = 1)
har = har.drop("2013-14", axis = 1)
har = har.drop("2015-16", axis = 1)
har = har.drop("2016-17", axis = 1)
har
# Out:
#     S.No.                                               Item     2014-15
# 0       1                  Agriculture, forestry and fishing   8015238.0
# 1     1.1                                              Crops   4636731.0
# 2     1.2                                          Livestock   2916173.0
# 3     1.3                               Forestry and logging    352254.0
# 4     1.4                            Fishing and aquaculture    110080.0
# 5       2                               Mining and quarrying     25186.0
# 6   Total                                            Primary   8040424.0
# 7       3                                      Manufacturing   7756921.0
# 8       4  Electricity, gas, water supply & other utility...   1101919.0
# 9       5                                       Construction   3702571.0
# 10  Total                                          Secondary  12561411.0
# 11      6              Trade, repair, hotels and restaurants   4986319.0
# ...

# %%
har.loc[np.isnan(har['2014-15']),['2014-15']]=0
har
# Out:
#     S.No.                                               Item     2014-15
# 0       1                  Agriculture, forestry and fishing   8015238.0
# 1     1.1                                              Crops   4636731.0
# 2     1.2                                          Livestock   2916173.0
# 3     1.3                               Forestry and logging    352254.0
# 4     1.4                            Fishing and aquaculture    110080.0
# 5       2                               Mining and quarrying     25186.0
# 6   Total                                            Primary   8040424.0
# 7       3                                      Manufacturing   7756921.0
# 8       4  Electricity, gas, water supply & other utility...   1101919.0
# 9       5                                       Construction   3702571.0
# 10  Total                                          Secondary  12561411.0
# 11      6              Trade, repair, hotels and restaurants   4986319.0
# ...

# %%
har = har.assign(State='Haryana')[['State'] + har.columns.tolist()]
har = har.drop('S.No.',axis = 1)
har = har.reset_index(drop=True)
har
# Out:
#       State                                               Item     2014-15
# 0   Haryana                  Agriculture, forestry and fishing   8015238.0
# 1   Haryana                                              Crops   4636731.0
# 2   Haryana                                          Livestock   2916173.0
# 3   Haryana                               Forestry and logging    352254.0
# 4   Haryana                            Fishing and aquaculture    110080.0
# 5   Haryana                               Mining and quarrying     25186.0
# 6   Haryana                                            Primary   8040424.0
# 7   Haryana                                      Manufacturing   7756921.0
# 8   Haryana  Electricity, gas, water supply & other utility...   1101919.0
# 9   Haryana                                       Construction   3702571.0
# 10  Haryana                                          Secondary  12561411.0
# ...

# %%
him = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Himachal_Pradesh-GSVA_cur_2014-15.csv")
him
# Out:
#     S.No.                                               Item  2011-12  \
# 0       1                  Agriculture, forestry and fishing  1162626
# 1     1.1                                              Crops   673402
# 2     1.2                                          Livestock   115315
# 3     1.3                               Forestry and logging   368735
# 4     1.4                            Fishing and aquaculture     5175
# 5       2                               Mining and quarrying    28640
# 6   Total                                            Primary  1191266
# 7       3                                      Manufacturing  1799826
# 8       4  Electricity, gas, water supply & other utility...   602408
# 9       5                                       Construction   638216
# 10  Total                                          Secondary  3040450
# 11      6              Trade, repair, hotels and restaurants   456829
# ...

# %%
him = him.drop("2011-12", axis = 1)
him = him.drop("2012-13", axis = 1)
him = him.drop("2013-14", axis = 1)
him
# Out:
#     S.No.                                               Item   2014-15
# 0       1                  Agriculture, forestry and fishing   1514981
# 1     1.1                                              Crops    853758
# 2     1.2                                          Livestock    110304
# 3     1.3                               Forestry and logging    540950
# 4     1.4                            Fishing and aquaculture      9968
# 5       2                               Mining and quarrying     33385
# 6   Total                                            Primary   1548366
# 7       3                                      Manufacturing   2543637
# 8       4  Electricity, gas, water supply & other utility...    767268
# 9       5                                       Construction    808256
# 10  Total                                          Secondary   4119162
# 11      6              Trade, repair, hotels and restaurants    615496
# ...

# %%
him = him.assign(State= 'Himachal_Pradesh')[['State'] + him.columns.tolist()]
him = him.drop('S.No.',axis = 1)
him = him.reset_index(drop=True)
him
# Out:
#                State                                               Item  \
# 0   Himachal_Pradesh                  Agriculture, forestry and fishing
# 1   Himachal_Pradesh                                              Crops
# 2   Himachal_Pradesh                                          Livestock
# 3   Himachal_Pradesh                               Forestry and logging
# 4   Himachal_Pradesh                            Fishing and aquaculture
# 5   Himachal_Pradesh                               Mining and quarrying
# 6   Himachal_Pradesh                                            Primary
# 7   Himachal_Pradesh                                      Manufacturing
# 8   Himachal_Pradesh  Electricity, gas, water supply & other utility...
# 9   Himachal_Pradesh                                       Construction
# 10  Himachal_Pradesh                                          Secondary
# 11  Himachal_Pradesh              Trade, repair, hotels and restaurants
# ...

# %%
jha = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Jharkhand-GSVA_cur_2015-16.csv")
jha
# Out:
#     S.No.                                               Item   2011-12  \
# 0       1                  Agriculture, forestry and fishing   2233546
# 1     1.1                                              Crops   1342099
# 2     1.2                                          Livestock    477585
# 3     1.3                               Forestry and logging    357560
# 4     1.4                            Fishing and aquaculture     56302
# 5       2                               Mining and quarrying   1620374
# 6   Total                                            Primary   3853920
# 7       3                                      Manufacturing   3016583
# 8       4  Electricity, gas, water supply & other utility...    241235
# 9       5                                       Construction   1439526
# 10  Total                                          Secondary   4697344
# 11      6              Trade, repair, hotels and restaurants   1152143
# ...

# %%
jha = jha.drop("2011-12", axis = 1)
jha = jha.drop("2012-13", axis = 1)
jha = jha.drop("2013-14", axis = 1)
jha = jha.drop("2015-16", axis = 1)
jha
# Out:
#     S.No.                                               Item   2014-15
# 0       1                  Agriculture, forestry and fishing   3211065
# 1     1.1                                              Crops   2094466
# 2     1.2                                          Livestock    562503
# 3     1.3                               Forestry and logging    445149
# 4     1.4                            Fishing and aquaculture    108947
# 5       2                               Mining and quarrying   2037289
# 6   Total                                            Primary   5248354
# 7       3                                      Manufacturing   4114148
# 8       4  Electricity, gas, water supply & other utility...    337489
# 9       5                                       Construction   1789834
# 10  Total                                          Secondary   6241471
# 11      6              Trade, repair, hotels and restaurants   1991359
# ...

# %%
jha = jha.assign(State='Jharkhand')[['State'] + jha.columns.tolist()]
jha = jha.drop('S.No.',axis = 1)
jha = jha.reset_index(drop=True)
jha
# Out:
#         State                                               Item   2014-15
# 0   Jharkhand                  Agriculture, forestry and fishing   3211065
# 1   Jharkhand                                              Crops   2094466
# 2   Jharkhand                                          Livestock    562503
# 3   Jharkhand                               Forestry and logging    445149
# 4   Jharkhand                            Fishing and aquaculture    108947
# 5   Jharkhand                               Mining and quarrying   2037289
# 6   Jharkhand                                            Primary   5248354
# 7   Jharkhand                                      Manufacturing   4114148
# 8   Jharkhand  Electricity, gas, water supply & other utility...    337489
# 9   Jharkhand                                       Construction   1789834
# 10  Jharkhand                                          Secondary   6241471
# ...

# %%
kar = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Karnataka-GSVA_cur_2015-16.csv")
kar
# Out:
#     S.No.                                               Item   2011-12  \
# 0       1                  Agriculture, forestry and fishing   7554868
# 1     1.1                                              Crops   5339455
# 2     1.2                                          Livestock   1349662
# 3     1.3                               Forestry and logging    593458
# 4     1.4                            Fishing and aquaculture    272293
# 5       2                               Mining and quarrying    450254
# 6   Total                                            Primary   8005122
# 7       3                                      Manufacturing   9713888
# 8       4  Electricity, gas, water supply & other utility...   1082882
# 9       5                                       Construction   5033145
# 10  Total                                          Secondary  15829915
# 11      6              Trade, repair, hotels and restaurants   6044367
# ...

# %%
kar = kar.drop("2011-12", axis = 1)
kar = kar.drop("2012-13", axis = 1)
kar = kar.drop("2013-14", axis = 1)
kar = kar.drop("2015-16", axis = 1)
kar
# Out:
#     S.No.                                               Item   2014-15
# 0       1                  Agriculture, forestry and fishing  11219422
# 1     1.1                                              Crops   8157179
# 2     1.2                                          Livestock   1868771
# 3     1.3                               Forestry and logging    693082
# 4     1.4                            Fishing and aquaculture    500390
# 5       2                               Mining and quarrying    846882
# 6   Total                                            Primary  12066304
# 7       3                                      Manufacturing  12953843
# 8       4  Electricity, gas, water supply & other utility...   1425762
# 9       5                                       Construction   6104799
# 10  Total                                          Secondary  20484404
# 11      6              Trade, repair, hotels and restaurants   8991658
# ...

# %%
kar = kar.assign(State='Karnataka')[['State'] + kar.columns.tolist()]
kar = kar.drop('S.No.',axis = 1)
kar = kar.reset_index(drop=True)
kar
# Out:
#         State                                               Item   2014-15
# 0   Karnataka                  Agriculture, forestry and fishing  11219422
# 1   Karnataka                                              Crops   8157179
# 2   Karnataka                                          Livestock   1868771
# 3   Karnataka                               Forestry and logging    693082
# 4   Karnataka                            Fishing and aquaculture    500390
# 5   Karnataka                               Mining and quarrying    846882
# 6   Karnataka                                            Primary  12066304
# 7   Karnataka                                      Manufacturing  12953843
# 8   Karnataka  Electricity, gas, water supply & other utility...   1425762
# 9   Karnataka                                       Construction   6104799
# 10  Karnataka                                          Secondary  20484404
# ...

# %%
ker = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Kerala-GSVA_cur_2015-16.csv")
ker
# Out:
#     S.No.                                               Item   2011-12  \
# 0       1                  Agriculture, forestry and fishing   4837594
# 1     1.1                                              Crops   2904593
# 2     1.2                                          Livestock   1125351
# 3     1.3                               Forestry and logging    430286
# 4     1.4                            Fishing and aquaculture    377363
# 5       2                               Mining and quarrying    272483
# 6   Total                                            Primary   5110077
# 7       3                                      Manufacturing   3420404
# 8       4  Electricity, gas, water supply & other utility...    467898
# 9       5                                       Construction   5308794
# 10  Total                                          Secondary   9197095
# 11      6              Trade, repair, hotels and restaurants   5321692
# ...

# %%
ker = ker.drop("2011-12", axis = 1)
ker = ker.drop("2012-13", axis = 1)
ker = ker.drop("2013-14", axis = 1)
ker = ker.drop("2015-16", axis = 1)
ker
# Out:
#     S.No.                                               Item   2014-15
# 0       1                  Agriculture, forestry and fishing   5930617
# 1     1.1                                              Crops   3070386
# 2     1.2                                          Livestock   1656104
# 3     1.3                               Forestry and logging    499808
# 4     1.4                            Fishing and aquaculture    704319
# 5       2                               Mining and quarrying    558824
# 6   Total                                            Primary   6489442
# 7       3                                      Manufacturing   4273567
# 8       4  Electricity, gas, water supply & other utility...    482470
# 9       5                                       Construction   7314003
# 10  Total                                          Secondary  12070040
# 11      6              Trade, repair, hotels and restaurants   8557345
# ...

# %%
ker = ker.assign(State='Kerala')[['State'] + ker.columns.tolist()]
ker = ker.drop('S.No.',axis = 1)
ker = ker.reset_index(drop=True)
ker
# Out:
#      State                                               Item   2014-15
# 0   Kerala                  Agriculture, forestry and fishing   5930617
# 1   Kerala                                              Crops   3070386
# 2   Kerala                                          Livestock   1656104
# 3   Kerala                               Forestry and logging    499808
# 4   Kerala                            Fishing and aquaculture    704319
# 5   Kerala                               Mining and quarrying    558824
# 6   Kerala                                            Primary   6489442
# 7   Kerala                                      Manufacturing   4273567
# 8   Kerala  Electricity, gas, water supply & other utility...    482470
# 9   Kerala                                       Construction   7314003
# 10  Kerala                                          Secondary  12070040
# 11  Kerala              Trade, repair, hotels and restaurants   8557345
# ...

# %%
mp = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Madhya_Pradesh-GSVA_cur_2016-17.csv")
mp
# Out:
#     S.No.                                               Item   2011-12  \
# 0       1                  Agriculture, forestry and fishing   9107231
# 1     1.1                                              Crops   7333369
# 2     1.2                                          Livestock    897640
# 3     1.3                               Forestry and logging    811315
# 4     1.4                            Fishing and aquaculture     64907
# 5       2                               Mining and quarrying   1171195
# 6   Total                                            Primary  10278426
# 7       3                                      Manufacturing   3828625
# 8       4  Electricity, gas, water supply & other utility...    903127
# 9       5                                       Construction   3495447
# 10  Total                                          Secondary   8227199
# 11      6              Trade, repair, hotels and restaurants   3378935
# ...

# %%
mp = mp.drop("2011-12", axis = 1)
mp = mp.drop("2012-13", axis = 1)
mp = mp.drop("2013-14", axis = 1)
mp = mp.drop("2015-16", axis = 1)
mp = mp.drop("2016-17", axis = 1)
mp
# Out:
#     S.No.                                               Item   2014-15
# 0       1                  Agriculture, forestry and fishing  16235647
# 1     1.1                                              Crops  13216013
# 2     1.2                                          Livestock   1932769
# 3     1.3                               Forestry and logging    965588
# 4     1.4                            Fishing and aquaculture    121277
# 5       2                               Mining and quarrying   1618373
# 6   Total                                            Primary  17854020
# 7       3                                      Manufacturing   4368833
# 8       4  Electricity, gas, water supply & other utility...   1272905
# 9       5                                       Construction   4403151
# 10  Total                                          Secondary  10044889
# 11      6              Trade, repair, hotels and restaurants   5357515
# ...

# %%
mp = mp.assign(State='Madhya_Pradesh')[['State'] + mp.columns.tolist()]
mp = mp.drop('S.No.',axis = 1)
mp = mp.reset_index(drop=True)
mp
# Out:
#              State                                               Item  \
# 0   Madhya_Pradesh                  Agriculture, forestry and fishing
# 1   Madhya_Pradesh                                              Crops
# 2   Madhya_Pradesh                                          Livestock
# 3   Madhya_Pradesh                               Forestry and logging
# 4   Madhya_Pradesh                            Fishing and aquaculture
# 5   Madhya_Pradesh                               Mining and quarrying
# 6   Madhya_Pradesh                                            Primary
# 7   Madhya_Pradesh                                      Manufacturing
# 8   Madhya_Pradesh  Electricity, gas, water supply & other utility...
# 9   Madhya_Pradesh                                       Construction
# 10  Madhya_Pradesh                                          Secondary
# 11  Madhya_Pradesh              Trade, repair, hotels and restaurants
# ...

# %%
mah = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Maharashtra-GSVA_cur_2014-15.csv")
mah
# Out:
#     S.No.                                               Item    2011-12  \
# 0       1                  Agriculture, forestry and fishing   14517809
# 1     1.1                                              Crops    9851618
# 2     1.2                                          Livestock    2855741
# 3     1.3                               Forestry and logging    1516574
# 4     1.4                            Fishing and aquaculture     293875
# 5       2                               Mining and quarrying    5649313
# 6   Total                                            Primary   20167122
# 7       3                                      Manufacturing   24603175
# 8       4  Electricity, gas, water supply & other utility...    2617289
# 9       5                                       Construction    7863028
# 10  Total                                          Secondary   35083491
# 11      6              Trade, repair, hotels and restaurants   10560911
# ...

# %%
mah = mah.drop("2011-12", axis = 1)
mah = mah.drop("2012-13", axis = 1)
mah = mah.drop("2013-14", axis = 1)
mah
# Out:
#     S.No.                                               Item    2014-15
# 0       1                  Agriculture, forestry and fishing   16475655
# 1     1.1                                              Crops   10435121
# 2     1.2                                          Livestock    3972829
# 3     1.3                               Forestry and logging    1592564
# 4     1.4                            Fishing and aquaculture     475141
# 5       2                               Mining and quarrying    5282727
# 6   Total                                            Primary   21758383
# 7       3                                      Manufacturing   33660294
# 8       4  Electricity, gas, water supply & other utility...    4334702
# 9       5                                       Construction    9450211
# 10  Total                                          Secondary   47445207
# 11      6              Trade, repair, hotels and restaurants   15839100
# ...

# %%
mah = mah.assign(State='Maharashtra')[['State'] + mah.columns.tolist()]
mah = mah.drop('S.No.',axis = 1)
mah = mah.reset_index(drop=True)
mah
# Out:
#           State                                               Item    2014-15
# 0   Maharashtra                  Agriculture, forestry and fishing   16475655
# 1   Maharashtra                                              Crops   10435121
# 2   Maharashtra                                          Livestock    3972829
# 3   Maharashtra                               Forestry and logging    1592564
# 4   Maharashtra                            Fishing and aquaculture     475141
# 5   Maharashtra                               Mining and quarrying    5282727
# 6   Maharashtra                                            Primary   21758383
# 7   Maharashtra                                      Manufacturing   33660294
# 8   Maharashtra  Electricity, gas, water supply & other utility...    4334702
# 9   Maharashtra                                       Construction    9450211
# 10  Maharashtra                                          Secondary   47445207
# ...

# %%
man = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Manipur-GSVA_cur_2014-15.csv",encoding='iso-8859-1')
man
# Out:
#         S.No.                                               Item    2011-12  \
# 0           1                  Agriculture, forestry and fishing   251623.0
# 1         1.1                                              Crops   137772.0
# 2         1.2                                          Livestock    52587.0
# 3         1.3                               Forestry and logging    42183.0
# 4         1.4                            Fishing and aquaculture    19081.0
# 5   2.                                      Mining and quarrying        NaN
# 6       Total                                            Primary   251623.0
# 7   3.                                             Manufacturing    40990.0
# 8   4.         Electricity, gas, water supply & other utility...    54276.0
# 9   5.                                              Construction   100712.0
# 10      Total                                          Secondary   195978.0
# ...

# %%
man = man.drop("2011-12", axis = 1)
man = man.drop("2012-13", axis = 1)
man = man.drop("2013-14", axis = 1)
man
# Out:
#         S.No.                                               Item    2014-15
# 0           1                  Agriculture, forestry and fishing   383140.0
# 1         1.1                                              Crops   226583.0
# 2         1.2                                          Livestock    75483.0
# 3         1.3                               Forestry and logging    45831.0
# 4         1.4                            Fishing and aquaculture    35243.0
# 5   2.                                      Mining and quarrying        NaN
# 6       Total                                            Primary   383140.0
# 7   3.                                             Manufacturing    49501.0
# 8   4.         Electricity, gas, water supply & other utility...    27490.0
# 9   5.                                              Construction   143182.0
# 10      Total                                          Secondary   220173.0
# ...

# %%
man.loc[np.isnan(man['2014-15']),['2014-15']]=0
man
# Out:
#         S.No.                                               Item    2014-15
# 0           1                  Agriculture, forestry and fishing   383140.0
# 1         1.1                                              Crops   226583.0
# 2         1.2                                          Livestock    75483.0
# 3         1.3                               Forestry and logging    45831.0
# 4         1.4                            Fishing and aquaculture    35243.0
# 5   2.                                      Mining and quarrying        0.0
# 6       Total                                            Primary   383140.0
# 7   3.                                             Manufacturing    49501.0
# 8   4.         Electricity, gas, water supply & other utility...    27490.0
# 9   5.                                              Construction   143182.0
# 10      Total                                          Secondary   220173.0
# ...

# %%
man = man.assign(State='Manipur')[['State'] + man.columns.tolist()]
man = man.drop('S.No.',axis = 1)
man = man.reset_index(drop=True)
man
# Out:
#       State                                               Item    2014-15
# 0   Manipur                  Agriculture, forestry and fishing   383140.0
# 1   Manipur                                              Crops   226583.0
# 2   Manipur                                          Livestock    75483.0
# 3   Manipur                               Forestry and logging    45831.0
# 4   Manipur                            Fishing and aquaculture    35243.0
# 5   Manipur                               Mining and quarrying        0.0
# 6   Manipur                                            Primary   383140.0
# 7   Manipur                                      Manufacturing    49501.0
# 8   Manipur  Electricity, gas, water supply & other utility...    27490.0
# 9   Manipur                                       Construction   143182.0
# 10  Manipur                                          Secondary   220173.0
# 11  Manipur              Trade, repair, hotels and restaurants   262950.0
# ...

# %%
meg = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Meghalaya-GSVA_cur_2016-17.csv",encoding='iso-8859-1')
meg
# Out:
#     S.No.                                               Item    2011-12  \
# 0       1                  Agriculture, forestry and fishing   282868.0
# 1     1.1                                              Crops   163103.0
# 2     1.2                                          Livestock    59593.0
# 3     1.3                               Forestry and logging    56090.0
# 4     1.4                            Fishing and aquaculture     4082.0
# 5       2                               Mining and quarrying   139436.0
# 6   Total                                            Primary   422304.0
# 7       3                                      Manufacturing   464603.0
# 8       4  Electricity, gas, water supply & other utility...    45558.0
# 9       5                                       Construction   113619.0
# 10  Total                                          Secondary   623780.0
# 11      6              Trade, repair, hotels and restaurants   258058.0
# ...

# %%
meg = meg.drop("2011-12", axis = 1)
meg = meg.drop("2012-13", axis = 1)
meg = meg.drop("2013-14", axis = 1)
meg = meg.drop("2015-16", axis = 1)
meg = meg.drop("2016-17", axis = 1)
meg
# Out:
#     S.No.                                               Item    2014-15
# 0       1                  Agriculture, forestry and fishing   366521.0
# 1     1.1                                              Crops   223330.0
# 2     1.2                                          Livestock    72442.0
# 3     1.3                               Forestry and logging    61166.0
# 4     1.4                            Fishing and aquaculture     9583.0
# 5       2                               Mining and quarrying    84529.0
# 6   Total                                            Primary   451050.0
# 7       3                                      Manufacturing   433213.0
# 8       4  Electricity, gas, water supply & other utility...    54473.0
# 9       5                                       Construction   150256.0
# 10  Total                                          Secondary   637942.0
# 11      6              Trade, repair, hotels and restaurants   383974.0
# ...

# %%
meg.loc[np.isnan(meg['2014-15']),['2014-15']]=0
meg
# Out:
#     S.No.                                               Item    2014-15
# 0       1                  Agriculture, forestry and fishing   366521.0
# 1     1.1                                              Crops   223330.0
# 2     1.2                                          Livestock    72442.0
# 3     1.3                               Forestry and logging    61166.0
# 4     1.4                            Fishing and aquaculture     9583.0
# 5       2                               Mining and quarrying    84529.0
# 6   Total                                            Primary   451050.0
# 7       3                                      Manufacturing   433213.0
# 8       4  Electricity, gas, water supply & other utility...    54473.0
# 9       5                                       Construction   150256.0
# 10  Total                                          Secondary   637942.0
# 11      6              Trade, repair, hotels and restaurants   383974.0
# ...

# %%
meg = meg.assign(State='Meghalaya')[['State'] + meg.columns.tolist()]
meg = meg.drop('S.No.',axis = 1)
meg = meg.reset_index(drop=True)
meg
# Out:
#         State                                               Item    2014-15
# 0   Meghalaya                  Agriculture, forestry and fishing   366521.0
# 1   Meghalaya                                              Crops   223330.0
# 2   Meghalaya                                          Livestock    72442.0
# 3   Meghalaya                               Forestry and logging    61166.0
# 4   Meghalaya                            Fishing and aquaculture     9583.0
# 5   Meghalaya                               Mining and quarrying    84529.0
# 6   Meghalaya                                            Primary   451050.0
# 7   Meghalaya                                      Manufacturing   433213.0
# 8   Meghalaya  Electricity, gas, water supply & other utility...    54473.0
# 9   Meghalaya                                       Construction   150256.0
# 10  Meghalaya                                          Secondary   637942.0
# ...

# %%
miz = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Mizoram-GSVA_cur_2014-15.csv",encoding='iso-8859-1')
miz
# Out:
#     S.No.                                               Item  2011-12  \
# 0       1                  Agriculture, forestry and fishing   149468
# 1     1.1                                              Crops    75876
# 2     1.2                                          Livestock    30336
# 3     1.3                               Forestry and logging    38403
# 4     1.4                            Fishing and aquaculture     4853
# 5       2                               Mining and quarrying     5073
# 6   Total                                            Primary   154541
# 7       3                                      Manufacturing     6578
# 8       4  Electricity, gas, water supply & other utility...    51024
# 9       5                                       Construction    89328
# 10  Total                                          Secondary   146930
# 11      6              Trade, repair, hotels and restaurants    76482
# ...

# %%
miz = miz.drop("2011-12", axis = 1)
miz = miz.drop("2012-13", axis = 1)
miz = miz.drop("2013-14", axis = 1)
miz
# Out:
#     S.No.                                               Item  2014-15
# 0       1                  Agriculture, forestry and fishing   217010
# 1     1.1                                              Crops   116609
# 2     1.2                                          Livestock    45590
# 3     1.3                               Forestry and logging    47763
# 4     1.4                            Fishing and aquaculture     7048
# 5       2                               Mining and quarrying     8588
# 6   Total                                            Primary   225598
# 7       3                                      Manufacturing     8479
# 8       4  Electricity, gas, water supply & other utility...   128365
# 9       5                                       Construction   133228
# 10  Total                                          Secondary   270072
# 11      6              Trade, repair, hotels and restaurants   114315
# ...

# %%
miz = miz.assign(State='Mizoram')[['State'] + miz.columns.tolist()]
miz = miz.drop('S.No.',axis = 1)
miz = miz.reset_index(drop=True)
miz
# Out:
#       State                                               Item  2014-15
# 0   Mizoram                  Agriculture, forestry and fishing   217010
# 1   Mizoram                                              Crops   116609
# 2   Mizoram                                          Livestock    45590
# 3   Mizoram                               Forestry and logging    47763
# 4   Mizoram                            Fishing and aquaculture     7048
# 5   Mizoram                               Mining and quarrying     8588
# 6   Mizoram                                            Primary   225598
# 7   Mizoram                                      Manufacturing     8479
# 8   Mizoram  Electricity, gas, water supply & other utility...   128365
# 9   Mizoram                                       Construction   133228
# 10  Mizoram                                          Secondary   270072
# 11  Mizoram              Trade, repair, hotels and restaurants   114315
# ...

# %%
nag = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Nagaland-GSVA_cur_2014-15.csv",encoding='iso-8859-1')
nag
# Out:
#     S.No.                                               Item  2011-12  \
# 0       1                  Agriculture, forestry and fishing   373363
# 1     1.1                                              Crops   204304
# 2     1.2                                          Livestock    83147
# 3     1.3                               Forestry and logging    79569
# 4     1.4                            Fishing and aquaculture     6344
# 5       2                               Mining and quarrying     5660
# 6   Total                                            Primary   379022
# 7       3                                      Manufacturing    15122
# 8       4  Electricity, gas, water supply & other utility...    29524
# 9       5                                       Construction   105135
# 10  Total                                          Secondary   149782
# 11      6              Trade, repair, hotels and restaurants   105152
# ...

# %%
nag = nag.drop("2011-12", axis = 1)
nag = nag.drop("2012-13", axis = 1)
nag = nag.drop("2013-14", axis = 1)
nag
# Out:
#     S.No.                                               Item  2014-15
# 0       1                  Agriculture, forestry and fishing   607897
# 1     1.1                                              Crops   375825
# 2     1.2                                          Livestock   123800
# 3     1.3                               Forestry and logging    99802
# 4     1.4                            Fishing and aquaculture     8470
# 5       2                               Mining and quarrying     8280
# 6   Total                                            Primary   616178
# 7       3                                      Manufacturing    18346
# 8       4  Electricity, gas, water supply & other utility...    37944
# 9       5                                       Construction   156072
# 10  Total                                          Secondary   212361
# 11      6              Trade, repair, hotels and restaurants   140781
# ...

# %%
nag = nag.assign(State='Nagaland')[['State'] + nag.columns.tolist()]
nag = nag.drop('S.No.',axis = 1)
nag = nag.reset_index(drop=True)
nag
# Out:
#        State                                               Item  2014-15
# 0   Nagaland                  Agriculture, forestry and fishing   607897
# 1   Nagaland                                              Crops   375825
# 2   Nagaland                                          Livestock   123800
# 3   Nagaland                               Forestry and logging    99802
# 4   Nagaland                            Fishing and aquaculture     8470
# 5   Nagaland                               Mining and quarrying     8280
# 6   Nagaland                                            Primary   616178
# 7   Nagaland                                      Manufacturing    18346
# 8   Nagaland  Electricity, gas, water supply & other utility...    37944
# 9   Nagaland                                       Construction   156072
# 10  Nagaland                                          Secondary   212361
# 11  Nagaland              Trade, repair, hotels and restaurants   140781
# ...

# %%
odi = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Odisha-GSVA_cur_2016-17.csv",encoding='iso-8859-1')
odi
# Out:
#     S.No.                                               Item   2011-12  \
# 0       1                  Agriculture, forestry and fishing   3899782
# 1     1.1                                              Crops   2508626
# 2     1.2                                          Livestock    538480
# 3     1.3                               Forestry and logging    584641
# 4     1.4                            Fishing and aquaculture    268035
# 5       2                               Mining and quarrying   2648738
# 6   Total                                            Primary   6548520
# 7       3                                      Manufacturing   4116404
# 8       4  Electricity, gas, water supply & other utility...    498975
# 9       5                                       Construction   2059629
# 10  Total                                          Secondary   6675009
# 11      6              Trade, repair, hotels and restaurants   2035854
# ...

# %%
odi = odi.drop("2011-12", axis = 1)
odi = odi.drop("2012-13", axis = 1)
odi = odi.drop("2013-14", axis = 1)
odi = odi.drop("2015-16", axis = 1)
odi = odi.drop("2016-17", axis = 1)
odi
# Out:
#     S.No.                                               Item   2014-15
# 0       1                  Agriculture, forestry and fishing   6422978
# 1     1.1                                              Crops   4382636
# 2     1.2                                          Livestock    788243
# 3     1.3                               Forestry and logging    791463
# 4     1.4                            Fishing and aquaculture    460636
# 5       2                               Mining and quarrying   2586328
# 6   Total                                            Primary   9009306
# 7       3                                      Manufacturing   5754229
# 8       4  Electricity, gas, water supply & other utility...    833067
# 9       5                                       Construction   2402396
# 10  Total                                          Secondary   8989693
# 11      6              Trade, repair, hotels and restaurants   3149555
# ...

# %%
odi = odi.assign(State='Orissa')[['State'] + odi.columns.tolist()]
odi = odi.drop('S.No.',axis = 1)
odi = odi.reset_index(drop=True)
odi
# Out:
#      State                                               Item   2014-15
# 0   Orissa                  Agriculture, forestry and fishing   6422978
# 1   Orissa                                              Crops   4382636
# 2   Orissa                                          Livestock    788243
# 3   Orissa                               Forestry and logging    791463
# 4   Orissa                            Fishing and aquaculture    460636
# 5   Orissa                               Mining and quarrying   2586328
# 6   Orissa                                            Primary   9009306
# 7   Orissa                                      Manufacturing   5754229
# 8   Orissa  Electricity, gas, water supply & other utility...    833067
# 9   Orissa                                       Construction   2402396
# 10  Orissa                                          Secondary   8989693
# 11  Orissa              Trade, repair, hotels and restaurants   3149555
# ...

# %%
pun = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Punjab-GSVA_cur_2014-15.csv",encoding='iso-8859-1')
pun
# Out:
#     S.No.                                               Item   2011-12  \
# 0       1                  Agriculture, forestry and fishing   7816825
# 1     1.1                                              Crops   5007937
# 2     1.2                                          Livestock   2034580
# 3     1.3                               Forestry and logging    715707
# 4     1.4                            Fishing and aquaculture     58601
# 5       2                               Mining and quarrying      3682
# 6   Total                                            Primary   7820507
# 7       3                                      Manufacturing   3750728
# 8       4  Electricity, gas, water supply & other utility...    714903
# 9       5                                       Construction   1978423
# 10  Total                                          Secondary   6444054
# 11      6              Trade, repair, hotels and restaurants   2532467
# ...

# %%
pun = pun.drop("2011-12", axis = 1)
pun = pun.drop("2012-13", axis = 1)
pun = pun.drop("2013-14", axis = 1)
pun
# Out:
#     S.No.                                               Item   2014-15
# 0       1                  Agriculture, forestry and fishing   9285716
# 1     1.1                                              Crops   5690972
# 2     1.2                                          Livestock   2638842
# 3     1.3                               Forestry and logging    848245
# 4     1.4                            Fishing and aquaculture    107657
# 5       2                               Mining and quarrying     10354
# 6   Total                                            Primary   9296070
# 7       3                                      Manufacturing   4790341
# 8       4  Electricity, gas, water supply & other utility...    911611
# 9       5                                       Construction   2202962
# 10  Total                                          Secondary   7904914
# 11      6              Trade, repair, hotels and restaurants   4419919
# ...

# %%
pun = pun.assign(State='Punjab')[['State'] + pun.columns.tolist()]
pun = pun.drop('S.No.',axis = 1)
pun = pun.reset_index(drop=True)
pun
# Out:
#      State                                               Item   2014-15
# 0   Punjab                  Agriculture, forestry and fishing   9285716
# 1   Punjab                                              Crops   5690972
# 2   Punjab                                          Livestock   2638842
# 3   Punjab                               Forestry and logging    848245
# 4   Punjab                            Fishing and aquaculture    107657
# 5   Punjab                               Mining and quarrying     10354
# 6   Punjab                                            Primary   9296070
# 7   Punjab                                      Manufacturing   4790341
# 8   Punjab  Electricity, gas, water supply & other utility...    911611
# 9   Punjab                                       Construction   2202962
# 10  Punjab                                          Secondary   7904914
# 11  Punjab              Trade, repair, hotels and restaurants   4419919
# ...

# %%
raj = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Rajasthan-GSVA_cur_2014-15.csv",encoding='iso-8859-1')
raj
# Out:
#     S.No.                                               Item   2011-12  \
# 0       1                  Agriculture, forestry and fishing  11910650
# 1     1.1                                              Crops   7346942
# 2     1.2                                          Livestock   3113617
# 3     1.3                               Forestry and logging   1416986
# 4     1.4                            Fishing and aquaculture     33105
# 5       2                               Mining and quarrying   1841530
# 6   Total                                            Primary  13752181
# 7       3                                      Manufacturing   6666606
# 8       4  Electricity, gas, water supply & other utility...    763271
# 9       5                                       Construction   4359171
# 10  Total                                          Secondary  11789049
# 11      6              Trade, repair, hotels and restaurants   4374625
# ...

# %%
raj = raj.drop("2011-12", axis = 1)
raj = raj.drop("2012-13", axis = 1)
raj = raj.drop("2013-14", axis = 1)
raj
# Out:
#     S.No.                                               Item   2014-15
# 0       1                  Agriculture, forestry and fishing  15044394
# 1     1.1                                              Crops   7673441
# 2     1.2                                          Livestock   5356257
# 3     1.3                               Forestry and logging   1956660
# 4     1.4                            Fishing and aquaculture     58036
# 5       2                               Mining and quarrying   4069385
# 6   Total                                            Primary  19113780
# 7       3                                      Manufacturing   6552580
# 8       4  Electricity, gas, water supply & other utility...   1122888
# 9       5                                       Construction   5353326
# 10  Total                                          Secondary  13028794
# 11      6              Trade, repair, hotels and restaurants   7297290
# ...

# %%
raj = raj.assign(State='Rajasthan')[['State'] + raj.columns.tolist()]
raj = raj.drop('S.No.',axis = 1)
raj = raj.reset_index(drop=True)
raj
# Out:
#         State                                               Item   2014-15
# 0   Rajasthan                  Agriculture, forestry and fishing  15044394
# 1   Rajasthan                                              Crops   7673441
# 2   Rajasthan                                          Livestock   5356257
# 3   Rajasthan                               Forestry and logging   1956660
# 4   Rajasthan                            Fishing and aquaculture     58036
# 5   Rajasthan                               Mining and quarrying   4069385
# 6   Rajasthan                                            Primary  19113780
# 7   Rajasthan                                      Manufacturing   6552580
# 8   Rajasthan  Electricity, gas, water supply & other utility...   1122888
# 9   Rajasthan                                       Construction   5353326
# 10  Rajasthan                                          Secondary  13028794
# ...

# %%
sik = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Sikkim-GSVA_cur_2015-16.csv",encoding='iso-8859-1')
sik
# Out:
#     S.No.                                               Item  2011-12  \
# 0       1                  Agriculture, forestry and fishing    90137
# 1     1.1                                              Crops    78207
# 2     1.2                                          Livestock     7627
# 3     1.3                               Forestry and logging     4017
# 4     1.4                            Fishing and aquaculture      287
# 5       2                               Mining and quarrying      800
# 6   Total                                            Primary    90937
# 7       3                                      Manufacturing   430623
# 8       4  Electricity, gas, water supply & other utility...   186623
# 9       5                                       Construction    67095
# 10  Total                                          Secondary   684341
# 11      6              Trade, repair, hotels and restaurants    31446
# ...

# %%
sik = sik.drop("2011-12", axis = 1)
sik = sik.drop("2012-13", axis = 1)
sik = sik.drop("2013-14", axis = 1)
sik = sik.drop("2015-16", axis = 1)
sik
# Out:
#     S.No.                                               Item  2014-15
# 0       1                  Agriculture, forestry and fishing   137447
# 1     1.1                                              Crops   114976
# 2     1.2                                          Livestock    17338
# 3     1.3                               Forestry and logging     4529
# 4     1.4                            Fishing and aquaculture      604
# 5       2                               Mining and quarrying     1329
# 6   Total                                            Primary   138776
# 7       3                                      Manufacturing   550697
# 8       4  Electricity, gas, water supply & other utility...   212499
# 9       5                                       Construction    82058
# 10  Total                                          Secondary   845253
# 11      6              Trade, repair, hotels and restaurants    70568
# ...

# %%
sik = sik.assign(State='Sikkim')[['State'] + sik.columns.tolist()]
sik = sik.drop('S.No.',axis = 1)
sik
# Out:
#      State                                               Item  2014-15
# 0   Sikkim                  Agriculture, forestry and fishing   137447
# 1   Sikkim                                              Crops   114976
# 2   Sikkim                                          Livestock    17338
# 3   Sikkim                               Forestry and logging     4529
# 4   Sikkim                            Fishing and aquaculture      604
# 5   Sikkim                               Mining and quarrying     1329
# 6   Sikkim                                            Primary   138776
# 7   Sikkim                                      Manufacturing   550697
# 8   Sikkim  Electricity, gas, water supply & other utility...   212499
# 9   Sikkim                                       Construction    82058
# 10  Sikkim                                          Secondary   845253
# 11  Sikkim              Trade, repair, hotels and restaurants    70568
# ...

# %%
tn = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Tamil_Nadu-GSVA_cur_2016-17.csv",encoding='iso-8859-1')
tn
# Out:
#     S.No.                                               Item   2011-12  \
# 0       1                  Agriculture, forestry and fishing   8773221
# 1     1.1                                              Crops   5375639
# 2     1.2                                          Livestock   2617944
# 3     1.3                               Forestry and logging    355528
# 4     1.4                            Fishing and aquaculture    424110
# 5       2                               Mining and quarrying    326843
# 6   Total                                            Primary   9100064
# 7       3                                      Manufacturing  15176801
# 8       4  Electricity, gas, water supply & other utility...    795604
# 9       5                                       Construction   9247221
# 10  Total                                          Secondary  25219626
# 11      6              Trade, repair, hotels and restaurants   7930219
# ...

# %%
tn = tn.drop("2011-12", axis = 1)
tn = tn.drop("2012-13", axis = 1)
tn = tn.drop("2013-14", axis = 1)
tn = tn.drop("2015-16", axis = 1)
tn = tn.drop("2016-17", axis = 1)
tn
# Out:
#     S.No.                                               Item    2014-15
# 0       1                  Agriculture, forestry and fishing   13064238
# 1     1.1                                              Crops    7297820
# 2     1.2                                          Livestock    4693361
# 3     1.3                               Forestry and logging     392705
# 4     1.4                            Fishing and aquaculture     680352
# 5       2                               Mining and quarrying     265536
# 6   Total                                            Primary   13329774
# 7       3                                      Manufacturing   18914794
# 8       4  Electricity, gas, water supply & other utility...    1710379
# 9       5                                       Construction   12216718
# 10  Total                                          Secondary   32841892
# 11      6              Trade, repair, hotels and restaurants   12895842
# ...

# %%
tn = tn.assign(State='Tamil_Nadu')[['State'] + tn.columns.tolist()]
tn = tn.drop('S.No.',axis = 1)
tn
# Out:
#          State                                               Item    2014-15
# 0   Tamil_Nadu                  Agriculture, forestry and fishing   13064238
# 1   Tamil_Nadu                                              Crops    7297820
# 2   Tamil_Nadu                                          Livestock    4693361
# 3   Tamil_Nadu                               Forestry and logging     392705
# 4   Tamil_Nadu                            Fishing and aquaculture     680352
# 5   Tamil_Nadu                               Mining and quarrying     265536
# 6   Tamil_Nadu                                            Primary   13329774
# 7   Tamil_Nadu                                      Manufacturing   18914794
# 8   Tamil_Nadu  Electricity, gas, water supply & other utility...    1710379
# 9   Tamil_Nadu                                       Construction   12216718
# 10  Tamil_Nadu                                          Secondary   32841892
# ...

# %%
tel = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Telangana-GSVA_cur_2016-17.csv",encoding='iso-8859-1')
tel
# Out:
#     S.No.                                               Item   2011-12  \
# 0       1                  Agriculture, forestry and fishing   5461488
# 1     1.1                                              Crops   3236819
# 2     1.2                                          Livestock   1884801
# 3     1.3                               Forestry and logging    191725
# 4     1.4                            Fishing and aquaculture    148143
# 5       2                               Mining and quarrying   1106109
# 6   Total                                            Primary   6567597
# 7       3                                      Manufacturing   6215158
# 8       4  Electricity, gas, water supply & other utility...    783505
# 9       5                                       Construction   2278975
# 10  Total                                          Secondary   9277638
# 11      6              Trade, repair, hotels and restaurants   3747813
# ...

# %%
tel = tel.drop("2011-12", axis = 1)
tel = tel.drop("2012-13", axis = 1)
tel = tel.drop("2013-14", axis = 1)
tel = tel.drop("2015-16", axis = 1)
tel = tel.drop("2016-17", axis = 1)
tel
# Out:
#     S.No.                                               Item   2014-15
# 0       1                  Agriculture, forestry and fishing   7591501
# 1     1.1                                              Crops   4162493
# 2     1.2                                          Livestock   2951299
# 3     1.3                               Forestry and logging    210741
# 4     1.4                            Fishing and aquaculture    266968
# 5       2                               Mining and quarrying   1541853
# 6   Total                                            Primary   9133354
# 7       3                                      Manufacturing   6353711
# 8       4  Electricity, gas, water supply & other utility...    716266
# 9       5                                       Construction   2854024
# 10  Total                                          Secondary   9924001
# 11      6              Trade, repair, hotels and restaurants   6494607
# ...

# %%
tel = tel.assign(State='Telangana')[['State'] + tel.columns.tolist()]
tel = tel.drop('S.No.',axis = 1)
tel
# Out:
#         State                                               Item   2014-15
# 0   Telangana                  Agriculture, forestry and fishing   7591501
# 1   Telangana                                              Crops   4162493
# 2   Telangana                                          Livestock   2951299
# 3   Telangana                               Forestry and logging    210741
# 4   Telangana                            Fishing and aquaculture    266968
# 5   Telangana                               Mining and quarrying   1541853
# 6   Telangana                                            Primary   9133354
# 7   Telangana                                      Manufacturing   6353711
# 8   Telangana  Electricity, gas, water supply & other utility...    716266
# 9   Telangana                                       Construction   2854024
# 10  Telangana                                          Secondary   9924001
# ...

# %%
tri = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Tripura-GSVA_cur_2014-15.csv",encoding='iso-8859-1')
tri
# Out:
#     S.No.                                               Item    2011-12  \
# 0       1                  Agriculture, forestry and fishing   511201.0
# 1     1.1                                              Crops   318959.0
# 2     1.2                                          Livestock    33664.0
# 3     1.3                               Forestry and logging   109763.0
# 4     1.4                            Fishing and aquaculture    48815.0
# 5       2                               Mining and quarrying   118123.0
# 6   Total                                            Primary   629324.0
# 7       3                                      Manufacturing    72651.0
# 8       4  Electricity, gas, water supply & other utility...    44297.0
# 9       5                                       Construction   148327.0
# 10  Total                                          Secondary   265275.0
# 11      6              Trade, repair, hotels and restaurants   226839.0
# ...

# %%
tri = tri.drop("2011-12", axis = 1)
tri = tri.drop("2012-13", axis = 1)
tri = tri.drop("2013-14", axis = 1)
tri
# Out:
#     S.No.                                               Item    2014-15
# 0       1                  Agriculture, forestry and fishing   799825.0
# 1     1.1                                              Crops   397591.0
# 2     1.2                                          Livestock    88176.0
# 3     1.3                               Forestry and logging   145096.0
# 4     1.4                            Fishing and aquaculture   168961.0
# 5       2                               Mining and quarrying   142391.0
# 6   Total                                            Primary   942216.0
# 7       3                                      Manufacturing   228625.0
# 8       4  Electricity, gas, water supply & other utility...    77870.0
# 9       5                                       Construction   177899.0
# 10  Total                                          Secondary   484393.0
# 11      6              Trade, repair, hotels and restaurants   390423.0
# ...

# %%
tri.loc[np.isnan(tri['2014-15']),['2014-15']]=0
tri
# Out:
#     S.No.                                               Item    2014-15
# 0       1                  Agriculture, forestry and fishing   799825.0
# 1     1.1                                              Crops   397591.0
# 2     1.2                                          Livestock    88176.0
# 3     1.3                               Forestry and logging   145096.0
# 4     1.4                            Fishing and aquaculture   168961.0
# 5       2                               Mining and quarrying   142391.0
# 6   Total                                            Primary   942216.0
# 7       3                                      Manufacturing   228625.0
# 8       4  Electricity, gas, water supply & other utility...    77870.0
# 9       5                                       Construction   177899.0
# 10  Total                                          Secondary   484393.0
# 11      6              Trade, repair, hotels and restaurants   390423.0
# ...

# %%
tri = tri.assign(State='Tripura')[['State'] + tri.columns.tolist()]
tri = tri.drop('S.No.',axis = 1)
tri = tri.reset_index(drop=True)
tri
# Out:
#       State                                               Item    2014-15
# 0   Tripura                  Agriculture, forestry and fishing   799825.0
# 1   Tripura                                              Crops   397591.0
# 2   Tripura                                          Livestock    88176.0
# 3   Tripura                               Forestry and logging   145096.0
# 4   Tripura                            Fishing and aquaculture   168961.0
# 5   Tripura                               Mining and quarrying   142391.0
# 6   Tripura                                            Primary   942216.0
# 7   Tripura                                      Manufacturing   228625.0
# 8   Tripura  Electricity, gas, water supply & other utility...    77870.0
# 9   Tripura                                       Construction   177899.0
# 10  Tripura                                          Secondary   484393.0
# 11  Tripura              Trade, repair, hotels and restaurants   390423.0
# ...

# %%
up = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Uttar_Pradesh-GSVA_cur_2015-16.csv",encoding='iso-8859-1')
up
# Out:
#     S.No.                                               Item   2011-12  \
# 0       1                  Agriculture, forestry and fishing  18324305
# 1     1.1                                              Crops  12415418
# 2     1.2                                          Livestock   4382274
# 3     1.3                               Forestry and logging   1249516
# 4     1.4                            Fishing and aquaculture    277097
# 5       2                               Mining and quarrying    653517
# 6   Total                                            Primary  18977822
# 7       3                                      Manufacturing   8763582
# 8       4  Electricity, gas, water supply & other utility...    926846
# 9       5                                       Construction   8487701
# 10  Total                                          Secondary  18178129
# 11      6              Trade, repair, hotels and restaurants   6946589
# ...

# %%
up = up.drop("2011-12", axis = 1)
up = up.drop("2012-13", axis = 1)
up = up.drop("2013-14", axis = 1)
up = up.drop("2015-16", axis = 1)
up
# Out:
#     S.No.                                               Item    2014-15
# 0       1                  Agriculture, forestry and fishing   25097754
# 1     1.1                                              Crops   16215212
# 2     1.2                                          Livestock    7096876
# 3     1.3                               Forestry and logging    1404936
# 4     1.4                            Fishing and aquaculture     380730
# 5       2                               Mining and quarrying     901501
# 6   Total                                            Primary   25999255
# 7       3                                      Manufacturing   12261649
# 8       4  Electricity, gas, water supply & other utility...    2030625
# 9       5                                       Construction   11256450
# 10  Total                                          Secondary   25548724
# 11      6              Trade, repair, hotels and restaurants    9437243
# ...

# %%
up = up.assign(State='Uttar_Pradesh')[['State'] + up.columns.tolist()]
up = up.drop('S.No.',axis = 1)
up
# Out:
#             State                                               Item  \
# 0   Uttar_Pradesh                  Agriculture, forestry and fishing
# 1   Uttar_Pradesh                                              Crops
# 2   Uttar_Pradesh                                          Livestock
# 3   Uttar_Pradesh                               Forestry and logging
# 4   Uttar_Pradesh                            Fishing and aquaculture
# 5   Uttar_Pradesh                               Mining and quarrying
# 6   Uttar_Pradesh                                            Primary
# 7   Uttar_Pradesh                                      Manufacturing
# 8   Uttar_Pradesh  Electricity, gas, water supply & other utility...
# 9   Uttar_Pradesh                                       Construction
# 10  Uttar_Pradesh                                          Secondary
# 11  Uttar_Pradesh              Trade, repair, hotels and restaurants
# 12  Uttar_Pradesh                            Trade & repair services
# ...

# %%
utk = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\NAD-Uttarakhand-GSVA_cur_2015-16.csv",encoding='iso-8859-1')
utk
# Out:
#     S.No.                                               Item     2011-12  \
# 0       1                  Agriculture, forestry and fishing   1330208.0
# 1     1.1                                              Crops    764026.0
# 2     1.2                                          Livestock    287787.0
# 3     1.3                               Forestry and logging    274833.0
# 4     1.4                            Fishing and aquaculture      3562.0
# 5       2                               Mining and quarrying    186083.0
# 6   Total                                            Primary   1516291.0
# 7       3                                      Manufacturing   4365135.0
# 8       4  Electricity, gas, water supply & other utility...    398079.0
# 9       5                                       Construction    883766.0
# 10  Total                                          Secondary   5646980.0
# 11      6              Trade, repair, hotels and restaurants   1192897.0
# ...

# %%
utk = utk.drop("2011-12", axis = 1)
utk = utk.drop("2012-13", axis = 1)
utk = utk.drop("2013-14", axis = 1)
utk = utk.drop("2015-16", axis = 1)
utk
# Out:
#     S.No.                                               Item     2014-15
# 0       1                  Agriculture, forestry and fishing   1601423.0
# 1     1.1                                              Crops    866146.0
# 2     1.2                                          Livestock    391188.0
# 3     1.3                               Forestry and logging    339293.0
# 4     1.4                            Fishing and aquaculture      4796.0
# 5       2                               Mining and quarrying    244549.0
# 6   Total                                            Primary   1845972.0
# 7       3                                      Manufacturing   5866252.0
# 8       4  Electricity, gas, water supply & other utility...    433880.0
# 9       5                                       Construction   1342733.0
# 10  Total                                          Secondary   7642865.0
# 11      6              Trade, repair, hotels and restaurants   1743106.0
# ...

# %%
utk.loc[np.isnan(utk['2014-15']),['2014-15']]=0
utk
# Out:
#     S.No.                                               Item     2014-15
# 0       1                  Agriculture, forestry and fishing   1601423.0
# 1     1.1                                              Crops    866146.0
# 2     1.2                                          Livestock    391188.0
# 3     1.3                               Forestry and logging    339293.0
# 4     1.4                            Fishing and aquaculture      4796.0
# 5       2                               Mining and quarrying    244549.0
# 6   Total                                            Primary   1845972.0
# 7       3                                      Manufacturing   5866252.0
# 8       4  Electricity, gas, water supply & other utility...    433880.0
# 9       5                                       Construction   1342733.0
# 10  Total                                          Secondary   7642865.0
# 11      6              Trade, repair, hotels and restaurants   1743106.0
# ...

# %%
utk = utk.assign(State='Uttarakhand')[['State'] + utk.columns.tolist()]
utk = utk.drop('S.No.',axis = 1)
utk = utk.reset_index(drop=True)
utk
# Out:
#           State                                               Item     2014-15
# 0   Uttarakhand                  Agriculture, forestry and fishing   1601423.0
# 1   Uttarakhand                                              Crops    866146.0
# 2   Uttarakhand                                          Livestock    391188.0
# 3   Uttarakhand                               Forestry and logging    339293.0
# 4   Uttarakhand                            Fishing and aquaculture      4796.0
# 5   Uttarakhand                               Mining and quarrying    244549.0
# 6   Uttarakhand                                            Primary   1845972.0
# 7   Uttarakhand                                      Manufacturing   5866252.0
# 8   Uttarakhand  Electricity, gas, water supply & other utility...    433880.0
# 9   Uttarakhand                                       Construction   1342733.0
# 10  Uttarakhand                                          Secondary   7642865.0
# ...

# %%
#Merging the dataframes
a = ap.append(arp)
a
# Out:
#                 State                                               Item  \
# 0      Andhra_Pradesh                  Agriculture, forestry and fishing
# 1      Andhra_Pradesh                                              Crops
# 2      Andhra_Pradesh                                          Livestock
# 3      Andhra_Pradesh                               Forestry and logging
# 4      Andhra_Pradesh                            Fishing and aquaculture
# 5      Andhra_Pradesh                               Mining and quarrying
# 6      Andhra_Pradesh                                            Primary
# 7      Andhra_Pradesh                                      Manufacturing
# 8      Andhra_Pradesh  Electricity, gas, water supply & other utility...
# 9      Andhra_Pradesh                                       Construction
# 10     Andhra_Pradesh                                          Secondary
# 11     Andhra_Pradesh              Trade, repair, hotels and restaurants
# ...

# %%
b=a.append(asa)
b
# Out:
#              State                                               Item  \
# 0   Andhra_Pradesh                  Agriculture, forestry and fishing
# 1   Andhra_Pradesh                                              Crops
# 2   Andhra_Pradesh                                          Livestock
# 3   Andhra_Pradesh                               Forestry and logging
# 4   Andhra_Pradesh                            Fishing and aquaculture
# 5   Andhra_Pradesh                               Mining and quarrying
# 6   Andhra_Pradesh                                            Primary
# 7   Andhra_Pradesh                                      Manufacturing
# 8   Andhra_Pradesh  Electricity, gas, water supply & other utility...
# 9   Andhra_Pradesh                                       Construction
# 10  Andhra_Pradesh                                          Secondary
# 11  Andhra_Pradesh              Trade, repair, hotels and restaurants
# ...

# %%
c = b.append(bi)
d = c.append(ch)
e = d.append(goa)
f = e.append(guj)
g = f.append(har)
h = g.append(him)
i = h.append(jha)
j = i.append(kar)
k = j.append(ker)
l = k.append(mp)
m = l.append(mah)
n = m.append(man)
o = n.append(meg)
p = o.append(miz)
q = p.append(nag)
r = q.append(odi)
s = r.append(pun)
t = s.append(raj)
u = t.append(sik)
v = u.append(tn)
w = v.append(tel)
x = w.append(tri)
y = x.append(up)
z = y.append(utk)
z
# Out:
#              State                                               Item  \
# 0   Andhra_Pradesh                  Agriculture, forestry and fishing
# 1   Andhra_Pradesh                                              Crops
# 2   Andhra_Pradesh                                          Livestock
# 3   Andhra_Pradesh                               Forestry and logging
# 4   Andhra_Pradesh                            Fishing and aquaculture
# 5   Andhra_Pradesh                               Mining and quarrying
# 6   Andhra_Pradesh                                            Primary
# 7   Andhra_Pradesh                                      Manufacturing
# 8   Andhra_Pradesh  Electricity, gas, water supply & other utility...
# 9   Andhra_Pradesh                                       Construction
# 10  Andhra_Pradesh                                          Secondary
# 11  Andhra_Pradesh              Trade, repair, hotels and restaurants
# ...

# %%
#Changing the index to the state colummn
z= z.set_index("State")
z
# Out:
#                                                              Item     2014-15
# State
# Andhra_Pradesh                  Agriculture, forestry and fishing  14819416.0
# Andhra_Pradesh                                              Crops   7893514.0
# Andhra_Pradesh                                          Livestock   4309078.0
# Andhra_Pradesh                               Forestry and logging    346160.0
# Andhra_Pradesh                            Fishing and aquaculture   2270664.0
# Andhra_Pradesh                               Mining and quarrying   1484300.0
# Andhra_Pradesh                                            Primary  16303716.0
# Andhra_Pradesh                                      Manufacturing   4672266.0
# Andhra_Pradesh  Electricity, gas, water supply & other utility...   1151729.0
# Andhra_Pradesh                                       Construction   4664889.0
# Andhra_Pradesh                                          Secondary  10488884.0
# ...

# %%
# Taking out percapita GSDP of each state
gsdp = z.loc[z['Item']=='Per Capita GSDP (Rs.)', :]
gsdp
# Out:
#                                     Item   2014-15
# State
# Andhra_Pradesh     Per Capita GSDP (Rs.)  104977.0
# Arunachal_Pradesh  Per Capita GSDP (Rs.)  112718.0
# Assam              Per Capita GSDP (Rs.)   60621.0
# Bihar              Per Capita GSDP (Rs.)   33954.0
# Chattisgarh        Per Capita GSDP (Rs.)   86860.0
# Goa                Per Capita GSDP (Rs.)  271793.0
# Gujrat             Per Capita GSDP (Rs.)  141263.0
# Haryana            Per Capita GSDP (Rs.)  164077.0
# Himachal_Pradesh   Per Capita GSDP (Rs.)  147330.0
# Jharkhand          Per Capita GSDP (Rs.)   62091.0
# Karnataka          Per Capita GSDP (Rs.)  145141.0
# Kerala             Per Capita GSDP (Rs.)  154778.0
# Madhya_Pradesh     Per Capita GSDP (Rs.)   62989.0
# Maharashtra        Per Capita GSDP (Rs.)  152853.0
# Manipur            Per Capita GSDP (Rs.)   58442.0
# Meghalaya          Per Capita GSDP (Rs.)   76228.0
# Mizoram            Per Capita GSDP (Rs.)   97687.0
# ...

# %%
#Sorting the dataframe
gsdp = gsdp.sort_values("2014-15")
gsdp
# Out:
#                                     Item   2014-15
# State
# Bihar              Per Capita GSDP (Rs.)   33954.0
# Uttar_Pradesh      Per Capita GSDP (Rs.)   49450.0
# Manipur            Per Capita GSDP (Rs.)   58442.0
# Assam              Per Capita GSDP (Rs.)   60621.0
# Jharkhand          Per Capita GSDP (Rs.)   62091.0
# Madhya_Pradesh     Per Capita GSDP (Rs.)   62989.0
# Orissa             Per Capita GSDP (Rs.)   73979.0
# Meghalaya          Per Capita GSDP (Rs.)   76228.0
# Tripura            Per Capita GSDP (Rs.)   77358.0
# Rajasthan          Per Capita GSDP (Rs.)   84837.0
# Chattisgarh        Per Capita GSDP (Rs.)   86860.0
# Nagaland           Per Capita GSDP (Rs.)   89607.0
# Mizoram            Per Capita GSDP (Rs.)   97687.0
# Andhra_Pradesh     Per Capita GSDP (Rs.)  104977.0
# Arunachal_Pradesh  Per Capita GSDP (Rs.)  112718.0
# Punjab             Per Capita GSDP (Rs.)  126606.0
# Telangana          Per Capita GSDP (Rs.)  139035.0
# ...

# %%
# Ratio of Higher percapita GSDP to lower percapita GSDP
ratio = 271793/33954
ratio
# Out:
# 8.004741709371503

# %%
#Plotting the bar graph of per capita GSDP 
plt.figure(num=None,figsize=(12,12),dpi=80,facecolor='w',edgecolor='k')
sns.barplot(x=gsdp['2014-15'],y=gsdp.index,data = gsdp)
plt.title('Per Capita GSDP of year 2014-15')
plt.show()

# %% [markdown]
# - Top 5 states - Goa, Sikkim, Haryana, Kerala, Uttarakhand
# - Bottom 5 states - Bihar, Uttar Pradesh, Manipur, Assam, Jharkhand
# - Ratio of Highest percapita GSDP to lowest is 8.0

# %%
# Collecting the Primary,Secondary and Tertiary from Column Item
sectorGDP = z.loc[(z['Item']=='Primary')|(z['Item']=='Secondary')|(z['Item']=='Tertiary'), :]
sectorGDP
# Out:
#                         Item     2014-15
# State
# Andhra_Pradesh       Primary  16303716.0
# Andhra_Pradesh     Secondary  10488884.0
# Andhra_Pradesh      Tertiary  22032942.0
# Arunachal_Pradesh    Primary    716959.0
# Arunachal_Pradesh  Secondary    287489.0
# Arunachal_Pradesh   Tertiary    631844.0
# Assam                Primary   5326697.0
# Assam              Secondary   4033091.0
# Assam               Tertiary   9307109.0
# Bihar                Primary   8019997.0
# Bihar              Secondary   5984896.0
# Bihar               Tertiary  22179969.0
# Chattisgarh          Primary   6400817.0
# Chattisgarh        Secondary   8238886.0
# Chattisgarh         Tertiary   7588778.0
# Goa                  Primary    312129.0
# Goa                Secondary   1547536.0
# Goa                 Tertiary   1738217.0
# Gujrat               Primary  15887187.0
# Gujrat             Secondary  33023538.0
# Gujrat              Tertiary  30220377.0
# Haryana              Primary   8040424.0
# ...

# %%
# Summing up the Primary values
primary = sectorGDP.loc[sectorGDP['Item']=='Primary','2014-15'].sum()
primary
# Out:
# 216457264.0

# %%
#Summing up the Secondary values
Secondary = sectorGDP.loc[sectorGDP['Item']=='Secondary','2014-15'].sum()
Secondary
# Out:
# 285121981.0

# %%
#Summing UP the Tertiary values
Tertiary = sectorGDP.loc[sectorGDP['Item']=='Tertiary','2014-15'].sum()
Tertiary
# Out:
# 506443698.0

# %%
#Plotting the pie chart
values = [primary,Secondary,Tertiary]
labels = ['Primary','Secondary','Tertiary']
plt.pie(values, labels=labels, autopct='%1.1f%%')
plt.title("Sector's % contribution")
plt.show()

# %%
gsdp
# Out:
#                                     Item   2014-15
# State
# Bihar              Per Capita GSDP (Rs.)   33954.0
# Uttar_Pradesh      Per Capita GSDP (Rs.)   49450.0
# Manipur            Per Capita GSDP (Rs.)   58442.0
# Assam              Per Capita GSDP (Rs.)   60621.0
# Jharkhand          Per Capita GSDP (Rs.)   62091.0
# Madhya_Pradesh     Per Capita GSDP (Rs.)   62989.0
# Orissa             Per Capita GSDP (Rs.)   73979.0
# Meghalaya          Per Capita GSDP (Rs.)   76228.0
# Tripura            Per Capita GSDP (Rs.)   77358.0
# Rajasthan          Per Capita GSDP (Rs.)   84837.0
# Chattisgarh        Per Capita GSDP (Rs.)   86860.0
# Nagaland           Per Capita GSDP (Rs.)   89607.0
# Mizoram            Per Capita GSDP (Rs.)   97687.0
# Andhra_Pradesh     Per Capita GSDP (Rs.)  104977.0
# Arunachal_Pradesh  Per Capita GSDP (Rs.)  112718.0
# Punjab             Per Capita GSDP (Rs.)  126606.0
# Telangana          Per Capita GSDP (Rs.)  139035.0
# ...

# %%
quantile = gsdp.quantile([0.20,0.50,0.85,1],axis = 0)
quantile
# Out:
#        2014-15
# 0.20   65187.0
# 0.50  104977.0
# 0.85  153246.2
# 1.00  271793.0

# %%
c1 = gsdp.loc['Kerala':,:]
c1
# Out:
#                           Item   2014-15
# State
# Kerala   Per Capita GSDP (Rs.)  154778.0
# Haryana  Per Capita GSDP (Rs.)  164077.0
# Sikkim   Per Capita GSDP (Rs.)  240274.0
# Goa      Per Capita GSDP (Rs.)  271793.0

# %%
c2 = gsdp.loc['Andhra_Pradesh':'Uttarakhand',:]
c2
# Out:
#                                     Item   2014-15
# State
# Andhra_Pradesh     Per Capita GSDP (Rs.)  104977.0
# Arunachal_Pradesh  Per Capita GSDP (Rs.)  112718.0
# Punjab             Per Capita GSDP (Rs.)  126606.0
# Telangana          Per Capita GSDP (Rs.)  139035.0
# Gujrat             Per Capita GSDP (Rs.)  141263.0
# Karnataka          Per Capita GSDP (Rs.)  145141.0
# Tamil_Nadu         Per Capita GSDP (Rs.)  146503.0
# Himachal_Pradesh   Per Capita GSDP (Rs.)  147330.0
# Maharashtra        Per Capita GSDP (Rs.)  152853.0
# Uttarakhand        Per Capita GSDP (Rs.)  153076.0

# %%
c3 = gsdp.loc['Orissa':'Mizoram',:]
c3
# Out:
#                               Item  2014-15
# State
# Orissa       Per Capita GSDP (Rs.)  73979.0
# Meghalaya    Per Capita GSDP (Rs.)  76228.0
# Tripura      Per Capita GSDP (Rs.)  77358.0
# Rajasthan    Per Capita GSDP (Rs.)  84837.0
# Chattisgarh  Per Capita GSDP (Rs.)  86860.0
# Nagaland     Per Capita GSDP (Rs.)  89607.0
# Mizoram      Per Capita GSDP (Rs.)  97687.0

# %%
c4 = gsdp.loc[:'Madhya_Pradesh',:]
c4
# Out:
#                                  Item  2014-15
# State
# Bihar           Per Capita GSDP (Rs.)  33954.0
# Uttar_Pradesh   Per Capita GSDP (Rs.)  49450.0
# Manipur         Per Capita GSDP (Rs.)  58442.0
# Assam           Per Capita GSDP (Rs.)  60621.0
# Jharkhand       Per Capita GSDP (Rs.)  62091.0
# Madhya_Pradesh  Per Capita GSDP (Rs.)  62989.0

# %% [markdown]
# c1- States : Kerala, Haryana, Sikkim and Goa

# %%
ker
# Out:
#      State                                               Item   2014-15
# 0   Kerala                  Agriculture, forestry and fishing   5930617
# 1   Kerala                                              Crops   3070386
# 2   Kerala                                          Livestock   1656104
# 3   Kerala                               Forestry and logging    499808
# 4   Kerala                            Fishing and aquaculture    704319
# 5   Kerala                               Mining and quarrying    558824
# 6   Kerala                                            Primary   6489442
# 7   Kerala                                      Manufacturing   4273567
# 8   Kerala  Electricity, gas, water supply & other utility...    482470
# 9   Kerala                                       Construction   7314003
# 10  Kerala                                          Secondary  12070040
# 11  Kerala              Trade, repair, hotels and restaurants   8557345
# ...

# %%
ker1 = ker.drop(ker.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
ker1 = ker1.drop("State",axis =1)
ker1 = ker1.set_index("Item")
ker1
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                    5930617
# Mining and quarrying                                  558824
# Manufacturing                                        4273567
# Electricity, gas, water supply & other utility ...    482470
# Construction                                         7314003
# Trade, repair, hotels and restaurants                8557345
# Transport, storage, communication & services re...   4020934
# Financial services                                   2010306
# Real estate, ownership of dwelling & profession...   7287633
# Public administration                                2068915
# Other services                                       5728645
# TOTAL GSVA at basic prices                          48233259

# %%
har
# Out:
#       State                                               Item     2014-15
# 0   Haryana                  Agriculture, forestry and fishing   8015238.0
# 1   Haryana                                              Crops   4636731.0
# 2   Haryana                                          Livestock   2916173.0
# 3   Haryana                               Forestry and logging    352254.0
# 4   Haryana                            Fishing and aquaculture    110080.0
# 5   Haryana                               Mining and quarrying     25186.0
# 6   Haryana                                            Primary   8040424.0
# 7   Haryana                                      Manufacturing   7756921.0
# 8   Haryana  Electricity, gas, water supply & other utility...   1101919.0
# 9   Haryana                                       Construction   3702571.0
# 10  Haryana                                          Secondary  12561411.0
# ...

# %%
har1 = har.drop(har.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
har1 = har1.drop("State",axis =1)
har1 = har1.set_index("Item")
har1
# Out:
#                                                        2014-15
# Item
# Agriculture, forestry and fishing                    8015238.0
# Mining and quarrying                                   25186.0
# Manufacturing                                        7756921.0
# Electricity, gas, water supply & other utility ...   1101919.0
# Construction                                         3702571.0
# Trade, repair, hotels and restaurants                4986319.0
# Transport, storage, communication & services re...   2560623.0
# Financial services                                   1671486.0
# Real estate, ownership of dwelling & profession...   6970183.0
# Public administration                                1036377.0
# Other services                                       2001581.0
# TOTAL GSVA at basic prices                          39828404.0

# %%
sik
# Out:
#      State                                               Item  2014-15
# 0   Sikkim                  Agriculture, forestry and fishing   137447
# 1   Sikkim                                              Crops   114976
# 2   Sikkim                                          Livestock    17338
# 3   Sikkim                               Forestry and logging     4529
# 4   Sikkim                            Fishing and aquaculture      604
# 5   Sikkim                               Mining and quarrying     1329
# 6   Sikkim                                            Primary   138776
# 7   Sikkim                                      Manufacturing   550697
# 8   Sikkim  Electricity, gas, water supply & other utility...   212499
# 9   Sikkim                                       Construction    82058
# 10  Sikkim                                          Secondary   845253
# 11  Sikkim              Trade, repair, hotels and restaurants    70568
# ...

# %%
sik1 = sik.drop(sik.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
sik1 = sik1.drop("State",axis =1)
sik1 = sik1.set_index("Item")
sik1
# Out:
#                                                     2014-15
# Item
# Agriculture, forestry and fishing                    137447
# Mining and quarrying                                   1329
# Manufacturing                                        550697
# Electricity, gas, water supply & other utility ...   212499
# Construction                                          82058
# Trade, repair, hotels and restaurants                 70568
# Transport, storage, communication & services re...    47347
# Financial services                                    21079
# Real estate, ownership of dwelling & profession...    75330
# Public administration                                119514
# Other services                                       149265
# TOTAL GSVA at basic prices                          1467133

# %%
goa
# Out:
#    State                                               Item  2014-15
# 0    Goa                  Agriculture, forestry and fishing   308507
# 1    Goa                                              Crops   140421
# 2    Goa                                          Livestock    30141
# 3    Goa                               Forestry and logging    15744
# 4    Goa                            Fishing and aquaculture   122201
# 5    Goa                               Mining and quarrying     3622
# 6    Goa                                            Primary   312129
# 7    Goa                                      Manufacturing  1177608
# 8    Goa  Electricity, gas, water supply & other utility...   204110
# 9    Goa                                       Construction   165819
# 10   Goa                                          Secondary  1547536
# 11   Goa              Trade, repair, hotels and restaurants   380927
# 12   Goa                            Trade & repair services   343492
# ...

# %%
goa1 = goa.drop(goa.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
goa1 = goa1.drop("State",axis =1)
goa1 = goa1.set_index("Item")
goa1
# Out:
#                                                     2014-15
# Item
# Agriculture, forestry and fishing                    308507
# Mining and quarrying                                   3622
# Manufacturing                                       1177608
# Electricity, gas, water supply & other utility ...   204110
# Construction                                         165819
# Trade, repair, hotels and restaurants                380927
# Transport, storage, communication & services re...   189656
# Financial services                                   233618
# Real estate, ownership of dwelling & profession...   407099
# Public administration                                346486
# Other services                                       180431
# TOTAL GSVA at basic prices                          3597882

# %%
cl1 = pd.concat([goa1,sik1]).groupby(level=0).sum()
cl1
# Out:
#                                                     2014-15
# Item
# Agriculture, forestry and fishing                    445954
# Construction                                         247877
# Electricity, gas, water supply & other utility ...   416609
# Financial services                                   254697
# Manufacturing                                       1728305
# Mining and quarrying                                   4951
# Other services                                       329696
# Public administration                                466000
# Real estate, ownership of dwelling & profession...   482429
# TOTAL GSVA at basic prices                          5065015
# Trade, repair, hotels and restaurants                451495
# Transport, storage, communication & services re...   237003

# %%
cl2 = pd.concat([cl1,har1]).groupby(level=0).sum()
cl2
# Out:
#                                                        2014-15
# Item
# Agriculture, forestry and fishing                    8461192.0
# Construction                                         3950448.0
# Electricity, gas, water supply & other utility ...   1518528.0
# Financial services                                   1926183.0
# Manufacturing                                        9485226.0
# Mining and quarrying                                   30137.0
# Other services                                       2331277.0
# Public administration                                1502377.0
# Real estate, ownership of dwelling & profession...   7452612.0
# TOTAL GSVA at basic prices                          44893419.0
# Trade, repair, hotels and restaurants                5437814.0
# Transport, storage, communication & services re...   2797626.0

# %%
c1 = pd.concat([cl2,ker1]).groupby(level=0).sum()
c1
# Out:
#                                                        2014-15
# Item
# Agriculture, forestry and fishing                   14391809.0
# Construction                                        11264451.0
# Electricity, gas, water supply & other utility ...   2000998.0
# Financial services                                   3936489.0
# Manufacturing                                       13758793.0
# Mining and quarrying                                  588961.0
# Other services                                       8059922.0
# Public administration                                3571292.0
# Real estate, ownership of dwelling & profession...  14740245.0
# TOTAL GSVA at basic prices                          93126678.0
# Trade, repair, hotels and restaurants               13995159.0
# Transport, storage, communication & services re...   6818560.0

# %%
c1 = c1.sort_values('2014-15')
c1
# Out:
#                                                        2014-15
# Item
# Mining and quarrying                                  588961.0
# Electricity, gas, water supply & other utility ...   2000998.0
# Public administration                                3571292.0
# Financial services                                   3936489.0
# Transport, storage, communication & services re...   6818560.0
# Other services                                       8059922.0
# Construction                                        11264451.0
# Manufacturing                                       13758793.0
# Trade, repair, hotels and restaurants               13995159.0
# Agriculture, forestry and fishing                   14391809.0
# Real estate, ownership of dwelling & profession...  14740245.0
# TOTAL GSVA at basic prices                          93126678.0

# %% [markdown]
# Top Sub-Sector which contribute 80% of the GSDP : Real estate, ownership of dwelling & professional services, Agriculture, forestry and fishing, Trade, repair, hotels and restaurants, Manufacturing and Construction

# %%
c1 = c1.loc[:'Real estate, ownership of dwelling & professional services',:]
c1
# Out:
#                                                        2014-15
# Item
# Mining and quarrying                                  588961.0
# Electricity, gas, water supply & other utility ...   2000998.0
# Public administration                                3571292.0
# Financial services                                   3936489.0
# Transport, storage, communication & services re...   6818560.0
# Other services                                       8059922.0
# Construction                                        11264451.0
# Manufacturing                                       13758793.0
# Trade, repair, hotels and restaurants               13995159.0
# Agriculture, forestry and fishing                   14391809.0
# Real estate, ownership of dwelling & profession...  14740245.0

# %%
plt.figure(figsize= (10,10))
plt.pie(c1['2014-15'], labels = c1.index,autopct='%1.1f%%')
plt.title("Sub-Sector's % contribution of ctegory- C1")
plt.show()

# %% [markdown]
# c2 - states : Andhra Pradesh, Arunachal Pradesh, Gujrat, Himachal Pradesh, Karnataka, Maharashtra, Punjab, Tamil Nadu, Telangana, Uttarakhand

# %%
ap
# Out:
#              State                                               Item  \
# 0   Andhra_Pradesh                  Agriculture, forestry and fishing
# 1   Andhra_Pradesh                                              Crops
# 2   Andhra_Pradesh                                          Livestock
# 3   Andhra_Pradesh                               Forestry and logging
# 4   Andhra_Pradesh                            Fishing and aquaculture
# 5   Andhra_Pradesh                               Mining and quarrying
# 6   Andhra_Pradesh                                            Primary
# 7   Andhra_Pradesh                                      Manufacturing
# 8   Andhra_Pradesh  Electricity, gas, water supply & other utility...
# 9   Andhra_Pradesh                                       Construction
# 10  Andhra_Pradesh                                          Secondary
# 11  Andhra_Pradesh              Trade, repair, hotels and restaurants
# ...

# %%
ap1 = ap.drop(ap.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
ap1 = ap1.drop("State",axis =1)
ap1 = ap1.set_index("Item")
ap1
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                   14819416
# Mining and quarrying                                 1484300
# Manufacturing                                        4672266
# Electricity, gas, water supply & other utility ...   1151729
# Construction                                         4664889
# Trade, repair, hotels and restaurants                4233400
# Transport, storage, communication & services re...   5076984
# Financial services                                   1900863
# Real estate, ownership of dwelling & profession...   4405409
# Public administration                                2200897
# Other services                                       4215389
# TOTAL GSVA at basic prices                          48825542

# %%
arp
# Out:
#                 State                                               Item  \
# 0   Arunachal_Pradesh                  Agriculture, forestry and fishing
# 1   Arunachal_Pradesh                                              Crops
# 2   Arunachal_Pradesh                                          Livestock
# 3   Arunachal_Pradesh                               Forestry and logging
# 4   Arunachal_Pradesh                            Fishing and aquaculture
# 5   Arunachal_Pradesh                               Mining and quarrying
# 6   Arunachal_Pradesh                                            Primary
# 7   Arunachal_Pradesh                                      Manufacturing
# 8   Arunachal_Pradesh  Electricity, gas, water supply & other utility...
# 9   Arunachal_Pradesh                                       Construction
# 10  Arunachal_Pradesh                                          Secondary
# 11  Arunachal_Pradesh              Trade, repair, hotels and restaurants
# ...

# %%
arp1 = arp.drop(arp.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
arp1 = arp1.drop("State",axis =1)
arp1 = arp1.set_index("Item")
arp1
# Out:
#                                                     2014-15
# Item
# Agriculture, forestry and fishing                    686117
# Mining and quarrying                                  30842
# Manufacturing                                         26120
# Electricity, gas, water supply & other utility ...   113527
# Construction                                         147842
# Trade, repair, hotels and restaurants                 60421
# Transport, storage, communication & services re...    35203
# Financial services                                    25207
# Real estate, ownership of dwelling & profession...    48418
# Public administration                                243867
# Other services                                       218728
# TOTAL GSVA at basic prices                          1636292

# %%
guj
# Out:
#      State                                               Item      2014-15
# 0   Gujrat                  Agriculture, forestry and fishing  13769969.00
# 1   Gujrat                                              Crops   9671086.00
# 2   Gujrat                                          Livestock   2698910.00
# 3   Gujrat                               Forestry and logging    761616.00
# 4   Gujrat                            Fishing and aquaculture    638357.00
# 5   Gujrat                               Mining and quarrying   2117218.00
# 6   Gujrat                                            Primary  15887187.00
# 7   Gujrat                                      Manufacturing  24087538.00
# 8   Gujrat  Electricity, gas, water supply & other utility...   3409983.00
# 9   Gujrat                                       Construction   5526017.00
# 10  Gujrat                                          Secondary  33023538.00
# ...

# %%
guj1 = guj.drop(guj.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
guj1 = guj1.drop("State",axis =1)
guj1 = guj1.set_index("Item")
guj1
# Out:
#                                                        2014-15
# Item
# Agriculture, forestry and fishing                   13769969.0
# Mining and quarrying                                 2117218.0
# Manufacturing                                       24087538.0
# Electricity, gas, water supply & other utility ...   3409983.0
# Construction                                         5526017.0
# Trade, repair, hotels and restaurants               10178713.0
# Transport, storage, communication & services re...   4555910.0
# Financial services                                   4606644.0
# Real estate, ownership of dwelling & profession...   5179502.0
# Public administration                                2576195.0
# Other services                                       3123413.0
# TOTAL GSVA at basic prices                          79131102.0

# %%
him
# Out:
#                State                                               Item  \
# 0   Himachal_Pradesh                  Agriculture, forestry and fishing
# 1   Himachal_Pradesh                                              Crops
# 2   Himachal_Pradesh                                          Livestock
# 3   Himachal_Pradesh                               Forestry and logging
# 4   Himachal_Pradesh                            Fishing and aquaculture
# 5   Himachal_Pradesh                               Mining and quarrying
# 6   Himachal_Pradesh                                            Primary
# 7   Himachal_Pradesh                                      Manufacturing
# 8   Himachal_Pradesh  Electricity, gas, water supply & other utility...
# 9   Himachal_Pradesh                                       Construction
# 10  Himachal_Pradesh                                          Secondary
# 11  Himachal_Pradesh              Trade, repair, hotels and restaurants
# ...

# %%
him1 = him.drop(him.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
him1 = him1.drop("State",axis =1)
him1 = him1.set_index("Item")
him1
# Out:
#                                                     2014-15
# Item
# Agriculture, forestry and fishing                   1514981
# Mining and quarrying                                  33385
# Manufacturing                                       2543637
# Electricity, gas, water supply & other utility ...   767268
# Construction                                         808256
# Trade, repair, hotels and restaurants                615496
# Transport, storage, communication & services re...   552234
# Financial services                                   362521
# Real estate, ownership of dwelling & profession...  1125937
# Public administration                                553974
# Other services                                       923164
# TOTAL GSVA at basic prices                          9800853

# %%
kar
# Out:
#         State                                               Item   2014-15
# 0   Karnataka                  Agriculture, forestry and fishing  11219422
# 1   Karnataka                                              Crops   8157179
# 2   Karnataka                                          Livestock   1868771
# 3   Karnataka                               Forestry and logging    693082
# 4   Karnataka                            Fishing and aquaculture    500390
# 5   Karnataka                               Mining and quarrying    846882
# 6   Karnataka                                            Primary  12066304
# 7   Karnataka                                      Manufacturing  12953843
# 8   Karnataka  Electricity, gas, water supply & other utility...   1425762
# 9   Karnataka                                       Construction   6104799
# 10  Karnataka                                          Secondary  20484404
# ...

# %%
kar1 = kar.drop(kar.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
kar1 = kar1.drop("State",axis =1)
kar1 = kar1.set_index("Item")
kar1
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                   11219422
# Mining and quarrying                                  846882
# Manufacturing                                       12953843
# Electricity, gas, water supply & other utility ...   1425762
# Construction                                         6104799
# Trade, repair, hotels and restaurants                8991658
# Transport, storage, communication & services re...   5097652
# Financial services                                   4094169
# Real estate, ownership of dwelling & profession...  24766393
# Public administration                                2232584
# Other services                                       5308174
# TOTAL GSVA at basic prices                          83041338

# %%
mah
# Out:
#           State                                               Item    2014-15
# 0   Maharashtra                  Agriculture, forestry and fishing   16475655
# 1   Maharashtra                                              Crops   10435121
# 2   Maharashtra                                          Livestock    3972829
# 3   Maharashtra                               Forestry and logging    1592564
# 4   Maharashtra                            Fishing and aquaculture     475141
# 5   Maharashtra                               Mining and quarrying    5282727
# 6   Maharashtra                                            Primary   21758383
# 7   Maharashtra                                      Manufacturing   33660294
# 8   Maharashtra  Electricity, gas, water supply & other utility...    4334702
# 9   Maharashtra                                       Construction    9450211
# 10  Maharashtra                                          Secondary   47445207
# ...

# %%
mah1 = mah.drop(mah.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
mah1 = mah1.drop("State",axis =1)
mah1 = mah1.set_index("Item")
mah1
# Out:
#                                                       2014-15
# Item
# Agriculture, forestry and fishing                    16475655
# Mining and quarrying                                  5282727
# Manufacturing                                        33660294
# Electricity, gas, water supply & other utility ...    4334702
# Construction                                          9450211
# Trade, repair, hotels and restaurants                15839100
# Transport, storage, communication & services re...    9697246
# Financial services                                   16143324
# Real estate, ownership of dwelling & profession...   30718051
# Public administration                                 5426991
# Other services                                       10806363
# TOTAL GSVA at basic prices                          157834665

# %%
pun
# Out:
#      State                                               Item   2014-15
# 0   Punjab                  Agriculture, forestry and fishing   9285716
# 1   Punjab                                              Crops   5690972
# 2   Punjab                                          Livestock   2638842
# 3   Punjab                               Forestry and logging    848245
# 4   Punjab                            Fishing and aquaculture    107657
# 5   Punjab                               Mining and quarrying     10354
# 6   Punjab                                            Primary   9296070
# 7   Punjab                                      Manufacturing   4790341
# 8   Punjab  Electricity, gas, water supply & other utility...    911611
# 9   Punjab                                       Construction   2202962
# 10  Punjab                                          Secondary   7904914
# 11  Punjab              Trade, repair, hotels and restaurants   4419919
# ...

# %%
pun1 = pun.drop(pun.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
pun1 = pun1.drop("State",axis =1)
pun1 = pun1.set_index("Item")
pun1
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                    9285716
# Mining and quarrying                                   10354
# Manufacturing                                        4790341
# Electricity, gas, water supply & other utility ...    911611
# Construction                                         2202962
# Trade, repair, hotels and restaurants                4419919
# Transport, storage, communication & services re...   1951809
# Financial services                                   2057520
# Real estate, ownership of dwelling & profession...   3142786
# Public administration                                1842730
# Other services                                       3303041
# TOTAL GSVA at basic prices                          33918789

# %%
tn
# Out:
#          State                                               Item    2014-15
# 0   Tamil_Nadu                  Agriculture, forestry and fishing   13064238
# 1   Tamil_Nadu                                              Crops    7297820
# 2   Tamil_Nadu                                          Livestock    4693361
# 3   Tamil_Nadu                               Forestry and logging     392705
# 4   Tamil_Nadu                            Fishing and aquaculture     680352
# 5   Tamil_Nadu                               Mining and quarrying     265536
# 6   Tamil_Nadu                                            Primary   13329774
# 7   Tamil_Nadu                                      Manufacturing   18914794
# 8   Tamil_Nadu  Electricity, gas, water supply & other utility...    1710379
# 9   Tamil_Nadu                                       Construction   12216718
# 10  Tamil_Nadu                                          Secondary   32841892
# ...

# %%
tn1 = tn.drop(tn.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
tn1 = tn1.drop("State",axis =1)
tn1 = tn1.set_index("Item")
tn1
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                   13064238
# Mining and quarrying                                  265536
# Manufacturing                                       18914794
# Electricity, gas, water supply & other utility ...   1710379
# Construction                                        12216718
# Trade, repair, hotels and restaurants               12895842
# Transport, storage, communication & services re...   7188320
# Financial services                                   5598498
# Real estate, ownership of dwelling & profession...  16830213
# Public administration                                3400800
# Other services                                       7430115
# TOTAL GSVA at basic prices                          99515453

# %%
tel
# Out:
#         State                                               Item   2014-15
# 0   Telangana                  Agriculture, forestry and fishing   7591501
# 1   Telangana                                              Crops   4162493
# 2   Telangana                                          Livestock   2951299
# 3   Telangana                               Forestry and logging    210741
# 4   Telangana                            Fishing and aquaculture    266968
# 5   Telangana                               Mining and quarrying   1541853
# 6   Telangana                                            Primary   9133354
# 7   Telangana                                      Manufacturing   6353711
# 8   Telangana  Electricity, gas, water supply & other utility...    716266
# 9   Telangana                                       Construction   2854024
# 10  Telangana                                          Secondary   9924001
# ...

# %%
tel1 = tel.drop(tel.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
tel1 = tel1.drop("State",axis =1)
tel1 = tel1.set_index("Item")
tel1
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                    7591501
# Mining and quarrying                                 1541853
# Manufacturing                                        6353711
# Electricity, gas, water supply & other utility ...    716266
# Construction                                         2854024
# Trade, repair, hotels and restaurants                6494607
# Transport, storage, communication & services re...   3604741
# Financial services                                   3023729
# Real estate, ownership of dwelling & profession...   9478839
# Public administration                                1711265
# Other services                                       4158229
# TOTAL GSVA at basic prices                          47528765

# %%
utk
# Out:
#           State                                               Item     2014-15
# 0   Uttarakhand                  Agriculture, forestry and fishing   1601423.0
# 1   Uttarakhand                                              Crops    866146.0
# 2   Uttarakhand                                          Livestock    391188.0
# 3   Uttarakhand                               Forestry and logging    339293.0
# 4   Uttarakhand                            Fishing and aquaculture      4796.0
# 5   Uttarakhand                               Mining and quarrying    244549.0
# 6   Uttarakhand                                            Primary   1845972.0
# 7   Uttarakhand                                      Manufacturing   5866252.0
# 8   Uttarakhand  Electricity, gas, water supply & other utility...    433880.0
# 9   Uttarakhand                                       Construction   1342733.0
# 10  Uttarakhand                                          Secondary   7642865.0
# ...

# %%
utk1 = utk.drop(utk.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
utk1 = utk1.drop("State",axis =1)
utk1 = utk1.set_index("Item")
utk1
# Out:
#                                                        2014-15
# Item
# Agriculture, forestry and fishing                    1601423.0
# Mining and quarrying                                  244549.0
# Manufacturing                                        5866252.0
# Electricity, gas, water supply & other utility ...    433880.0
# Construction                                         1342733.0
# Trade, repair, hotels and restaurants                1743106.0
# Transport, storage, communication & services re...   1066693.0
# Financial services                                    385030.0
# Real estate, ownership of dwelling & profession...    831307.0
# Public administration                                 579409.0
# Other services                                        982430.0
# TOTAL GSVA at basic prices                          15076812.0

# %%
c2 = pd.concat([ap1,arp1]).groupby(level=0).sum()
c2
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                   15505533
# Construction                                         4812731
# Electricity, gas, water supply & other utility ...   1265256
# Financial services                                   1926070
# Manufacturing                                        4698386
# Mining and quarrying                                 1515142
# Other services                                       4434117
# Public administration                                2444764
# Real estate, ownership of dwelling & profession...   4453827
# TOTAL GSVA at basic prices                          50461834
# Trade, repair, hotels and restaurants                4293821
# Transport, storage, communication & services re...   5112187

# %%
c2 = pd.concat([c2,guj1]).groupby(level=0).sum()
c2
# Out:
#                                                         2014-15
# Item
# Agriculture, forestry and fishing                    29275502.0
# Construction                                         10338748.0
# Electricity, gas, water supply & other utility ...    4675239.0
# Financial services                                    6532714.0
# Manufacturing                                        28785924.0
# Mining and quarrying                                  3632360.0
# Other services                                        7557530.0
# Public administration                                 5020959.0
# Real estate, ownership of dwelling & profession...    9633329.0
# TOTAL GSVA at basic prices                          129592936.0
# Trade, repair, hotels and restaurants                14472534.0
# Transport, storage, communication & services re...    9668097.0

# %%
c2 = pd.concat([c2,him1]).groupby(level=0).sum()
c2
# Out:
#                                                         2014-15
# Item
# Agriculture, forestry and fishing                    30790483.0
# Construction                                         11147004.0
# Electricity, gas, water supply & other utility ...    5442507.0
# Financial services                                    6895235.0
# Manufacturing                                        31329561.0
# Mining and quarrying                                  3665745.0
# Other services                                        8480694.0
# Public administration                                 5574933.0
# Real estate, ownership of dwelling & profession...   10759266.0
# TOTAL GSVA at basic prices                          139393789.0
# Trade, repair, hotels and restaurants                15088030.0
# Transport, storage, communication & services re...   10220331.0

# %%
c2 = pd.concat([c2,kar1]).groupby(level=0).sum()
c2
# Out:
#                                                         2014-15
# Item
# Agriculture, forestry and fishing                    42009905.0
# Construction                                         17251803.0
# Electricity, gas, water supply & other utility ...    6868269.0
# Financial services                                   10989404.0
# Manufacturing                                        44283404.0
# Mining and quarrying                                  4512627.0
# Other services                                       13788868.0
# Public administration                                 7807517.0
# Real estate, ownership of dwelling & profession...   35525659.0
# TOTAL GSVA at basic prices                          222435127.0
# Trade, repair, hotels and restaurants                24079688.0
# Transport, storage, communication & services re...   15317983.0

# %%
c2 = pd.concat([c2,mah1]).groupby(level=0).sum()
c2
# Out:
#                                                         2014-15
# Item
# Agriculture, forestry and fishing                    58485560.0
# Construction                                         26702014.0
# Electricity, gas, water supply & other utility ...   11202971.0
# Financial services                                   27132728.0
# Manufacturing                                        77943698.0
# Mining and quarrying                                  9795354.0
# Other services                                       24595231.0
# Public administration                                13234508.0
# Real estate, ownership of dwelling & profession...   66243710.0
# TOTAL GSVA at basic prices                          380269792.0
# Trade, repair, hotels and restaurants                39918788.0
# Transport, storage, communication & services re...   25015229.0

# %%
c2 = pd.concat([c2,pun1]).groupby(level=0).sum()
c2
# Out:
#                                                         2014-15
# Item
# Agriculture, forestry and fishing                    67771276.0
# Construction                                         28904976.0
# Electricity, gas, water supply & other utility ...   12114582.0
# Financial services                                   29190248.0
# Manufacturing                                        82734039.0
# Mining and quarrying                                  9805708.0
# Other services                                       27898272.0
# Public administration                                15077238.0
# Real estate, ownership of dwelling & profession...   69386496.0
# TOTAL GSVA at basic prices                          414188581.0
# Trade, repair, hotels and restaurants                44338707.0
# Transport, storage, communication & services re...   26967038.0

# %%
c2 = pd.concat([c2,tn1]).groupby(level=0).sum()
c2
# Out:
#                                                         2014-15
# Item
# Agriculture, forestry and fishing                    80835514.0
# Construction                                         41121694.0
# Electricity, gas, water supply & other utility ...   13824961.0
# Financial services                                   34788746.0
# Manufacturing                                       101648833.0
# Mining and quarrying                                 10071244.0
# Other services                                       35328387.0
# Public administration                                18478038.0
# Real estate, ownership of dwelling & profession...   86216709.0
# TOTAL GSVA at basic prices                          513704034.0
# Trade, repair, hotels and restaurants                57234549.0
# Transport, storage, communication & services re...   34155358.0

# %%
c2 = pd.concat([c2,tel1]).groupby(level=0).sum()
c2
# Out:
#                                                         2014-15
# Item
# Agriculture, forestry and fishing                    88427015.0
# Construction                                         43975718.0
# Electricity, gas, water supply & other utility ...   14541227.0
# Financial services                                   37812475.0
# Manufacturing                                       108002544.0
# Mining and quarrying                                 11613097.0
# Other services                                       39486616.0
# Public administration                                20189303.0
# Real estate, ownership of dwelling & profession...   95695548.0
# TOTAL GSVA at basic prices                          561232799.0
# Trade, repair, hotels and restaurants                63729156.0
# Transport, storage, communication & services re...   37760099.0

# %%
c2 = pd.concat([c2,utk1]).groupby(level=0).sum()
c2
# Out:
#                                                         2014-15
# Item
# Agriculture, forestry and fishing                    90028438.0
# Construction                                         45318451.0
# Electricity, gas, water supply & other utility ...   14975107.0
# Financial services                                   38197505.0
# Manufacturing                                       113868796.0
# Mining and quarrying                                 11857646.0
# Other services                                       40469046.0
# Public administration                                20768712.0
# Real estate, ownership of dwelling & profession...   96526855.0
# TOTAL GSVA at basic prices                          576309611.0
# Trade, repair, hotels and restaurants                65472262.0
# Transport, storage, communication & services re...   38826792.0

# %%
c2 = c2.sort_values('2014-15')
c2
# Out:
#                                                         2014-15
# Item
# Mining and quarrying                                 11857646.0
# Electricity, gas, water supply & other utility ...   14975107.0
# Public administration                                20768712.0
# Financial services                                   38197505.0
# Transport, storage, communication & services re...   38826792.0
# Other services                                       40469046.0
# Construction                                         45318451.0
# Trade, repair, hotels and restaurants                65472262.0
# Agriculture, forestry and fishing                    90028438.0
# Real estate, ownership of dwelling & profession...   96526855.0
# Manufacturing                                       113868796.0
# TOTAL GSVA at basic prices                          576309611.0

# %% [markdown]
# Top Sub-Sector which contribute 80% of the GSDP : Manufacturing, Real estate, ownership of dwelling & professional services, Agriculture, forestry and fishing, Trade, repair, hotels and restaurants, Construction, Other services

# %%
c2 = c2.loc[:'Manufacturing',:]
c2
# Out:
#                                                         2014-15
# Item
# Mining and quarrying                                 11857646.0
# Electricity, gas, water supply & other utility ...   14975107.0
# Public administration                                20768712.0
# Financial services                                   38197505.0
# Transport, storage, communication & services re...   38826792.0
# Other services                                       40469046.0
# Construction                                         45318451.0
# Trade, repair, hotels and restaurants                65472262.0
# Agriculture, forestry and fishing                    90028438.0
# Real estate, ownership of dwelling & profession...   96526855.0
# Manufacturing                                       113868796.0

# %%
plt.figure(figsize= (10,10))
plt.pie(c2['2014-15'], labels = c2.index, autopct='%1.1f%%')
plt.title("Sub-Sector's % contribution of Category C2")
plt.show()

# %% [markdown]
# c3 - states: Chattisgarh, Meghalaya, Mizoram, Nagaland, Orissa, Rajasthan and Tripura

# %%
ch
# Out:
#           State                                               Item   2014-15
# 0   Chattisgarh                  Agriculture, forestry and fishing   3948847
# 1   Chattisgarh                                              Crops   2613371
# 2   Chattisgarh                                          Livestock    352208
# 3   Chattisgarh                               Forestry and logging    597785
# 4   Chattisgarh                            Fishing and aquaculture    385483
# 5   Chattisgarh                               Mining and quarrying   2451970
# 6   Chattisgarh                                            Primary   6400817
# 7   Chattisgarh                                      Manufacturing   4370593
# 8   Chattisgarh  Electricity, gas, water supply & other utility...   1198438
# 9   Chattisgarh                                       Construction   2669855
# 10  Chattisgarh                                          Secondary   8238886
# ...

# %%
ch1 = ch.drop(ch.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
ch1 = ch1.drop("State",axis =1)
ch1 = ch1.set_index("Item")
ch1
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                    3948847
# Mining and quarrying                                 2451970
# Manufacturing                                        4370593
# Electricity, gas, water supply & other utility ...   1198438
# Construction                                         2669855
# Trade, repair, hotels and restaurants                1535571
# Transport, storage, communication & services re...    871770
# Financial services                                    739057
# Real estate, ownership of dwelling & profession...   2462166
# Public administration                                 867982
# Other services                                       1112232
# TOTAL GSVA at basic prices                          22228481

# %%
meg
# Out:
#         State                                               Item    2014-15
# 0   Meghalaya                  Agriculture, forestry and fishing   366521.0
# 1   Meghalaya                                              Crops   223330.0
# 2   Meghalaya                                          Livestock    72442.0
# 3   Meghalaya                               Forestry and logging    61166.0
# 4   Meghalaya                            Fishing and aquaculture     9583.0
# 5   Meghalaya                               Mining and quarrying    84529.0
# 6   Meghalaya                                            Primary   451050.0
# 7   Meghalaya                                      Manufacturing   433213.0
# 8   Meghalaya  Electricity, gas, water supply & other utility...    54473.0
# 9   Meghalaya                                       Construction   150256.0
# 10  Meghalaya                                          Secondary   637942.0
# ...

# %%
meg1 = meg.drop(meg.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
meg1 = meg1.drop("State",axis =1)
meg1 = meg1.set_index("Item")
meg1
# Out:
#                                                       2014-15
# Item
# Agriculture, forestry and fishing                    366521.0
# Mining and quarrying                                  84529.0
# Manufacturing                                        433213.0
# Electricity, gas, water supply & other utility ...    54473.0
# Construction                                         150256.0
# Trade, repair, hotels and restaurants                383974.0
# Transport, storage, communication & services re...   148189.0
# Financial services                                    64091.0
# Real estate, ownership of dwelling & profession...   150409.0
# Public administration                                239782.0
# Other services                                       214211.0
# TOTAL GSVA at basic prices                          2289647.0

# %%
miz
# Out:
#       State                                               Item  2014-15
# 0   Mizoram                  Agriculture, forestry and fishing   217010
# 1   Mizoram                                              Crops   116609
# 2   Mizoram                                          Livestock    45590
# 3   Mizoram                               Forestry and logging    47763
# 4   Mizoram                            Fishing and aquaculture     7048
# 5   Mizoram                               Mining and quarrying     8588
# 6   Mizoram                                            Primary   225598
# 7   Mizoram                                      Manufacturing     8479
# 8   Mizoram  Electricity, gas, water supply & other utility...   128365
# 9   Mizoram                                       Construction   133228
# 10  Mizoram                                          Secondary   270072
# 11  Mizoram              Trade, repair, hotels and restaurants   114315
# ...

# %%
miz1 = miz.drop(miz.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
miz1 = miz1.drop("State",axis =1)
miz1 = miz1.set_index("Item")
miz1
# Out:
#                                                     2014-15
# Item
# Agriculture, forestry and fishing                    217010
# Mining and quarrying                                   8588
# Manufacturing                                          8479
# Electricity, gas, water supply & other utility ...   128365
# Construction                                         133228
# Trade, repair, hotels and restaurants                114315
# Transport, storage, communication & services re...    52587
# Financial services                                    23168
# Real estate, ownership of dwelling & profession...    55068
# Public administration                                206259
# Other services                                       186222
# TOTAL GSVA at basic prices                          1133289

# %%
nag
# Out:
#        State                                               Item  2014-15
# 0   Nagaland                  Agriculture, forestry and fishing   607897
# 1   Nagaland                                              Crops   375825
# 2   Nagaland                                          Livestock   123800
# 3   Nagaland                               Forestry and logging    99802
# 4   Nagaland                            Fishing and aquaculture     8470
# 5   Nagaland                               Mining and quarrying     8280
# 6   Nagaland                                            Primary   616178
# 7   Nagaland                                      Manufacturing    18346
# 8   Nagaland  Electricity, gas, water supply & other utility...    37944
# 9   Nagaland                                       Construction   156072
# 10  Nagaland                                          Secondary   212361
# 11  Nagaland              Trade, repair, hotels and restaurants   140781
# ...

# %%
nag1 = nag.drop(nag.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
nag1 = nag1.drop("State",axis =1)
nag1 = nag1.set_index("Item")
nag1
# Out:
#                                                     2014-15
# Item
# Agriculture, forestry and fishing                    607897
# Mining and quarrying                                   8280
# Manufacturing                                         18346
# Electricity, gas, water supply & other utility ...    37944
# Construction                                         156072
# Trade, repair, hotels and restaurants                140781
# Transport, storage, communication & services re...    77521
# Financial services                                    60393
# Real estate, ownership of dwelling & profession...   159651
# Public administration                                295424
# Other services                                       259186
# TOTAL GSVA at basic prices                          1821495

# %%
odi
# Out:
#      State                                               Item   2014-15
# 0   Orissa                  Agriculture, forestry and fishing   6422978
# 1   Orissa                                              Crops   4382636
# 2   Orissa                                          Livestock    788243
# 3   Orissa                               Forestry and logging    791463
# 4   Orissa                            Fishing and aquaculture    460636
# 5   Orissa                               Mining and quarrying   2586328
# 6   Orissa                                            Primary   9009306
# 7   Orissa                                      Manufacturing   5754229
# 8   Orissa  Electricity, gas, water supply & other utility...    833067
# 9   Orissa                                       Construction   2402396
# 10  Orissa                                          Secondary   8989693
# 11  Orissa              Trade, repair, hotels and restaurants   3149555
# ...

# %%
odi1 = odi.drop(odi.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
odi1 = odi1.drop("State",axis =1)
odi1 = odi1.set_index("Item")
odi1
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                    6422978
# Mining and quarrying                                 2586328
# Manufacturing                                        5754229
# Electricity, gas, water supply & other utility ...    833067
# Construction                                         2402396
# Trade, repair, hotels and restaurants                3149555
# Transport, storage, communication & services re...   2034016
# Financial services                                   1065147
# Real estate, ownership of dwelling & profession...   2348714
# Public administration                                1318221
# Other services                                       2340603
# TOTAL GSVA at basic prices                          30255256

# %%
raj
# Out:
#         State                                               Item   2014-15
# 0   Rajasthan                  Agriculture, forestry and fishing  15044394
# 1   Rajasthan                                              Crops   7673441
# 2   Rajasthan                                          Livestock   5356257
# 3   Rajasthan                               Forestry and logging   1956660
# 4   Rajasthan                            Fishing and aquaculture     58036
# 5   Rajasthan                               Mining and quarrying   4069385
# 6   Rajasthan                                            Primary  19113780
# 7   Rajasthan                                      Manufacturing   6552580
# 8   Rajasthan  Electricity, gas, water supply & other utility...   1122888
# 9   Rajasthan                                       Construction   5353326
# 10  Rajasthan                                          Secondary  13028794
# ...

# %%
raj1 = raj.drop(raj.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
raj1 = raj1.drop("State",axis =1)
raj1 = raj1.set_index("Item")
raj1
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                   15044394
# Mining and quarrying                                 4069385
# Manufacturing                                        6552580
# Electricity, gas, water supply & other utility ...   1122888
# Construction                                         5353326
# Trade, repair, hotels and restaurants                7297290
# Transport, storage, communication & services re...   3814461
# Financial services                                   1827413
# Real estate, ownership of dwelling & profession...   6451997
# Public administration                                2460364
# Other services                                       4164287
# TOTAL GSVA at basic prices                          58158386

# %%
tri
# Out:
#       State                                               Item    2014-15
# 0   Tripura                  Agriculture, forestry and fishing   799825.0
# 1   Tripura                                              Crops   397591.0
# 2   Tripura                                          Livestock    88176.0
# 3   Tripura                               Forestry and logging   145096.0
# 4   Tripura                            Fishing and aquaculture   168961.0
# 5   Tripura                               Mining and quarrying   142391.0
# 6   Tripura                                            Primary   942216.0
# 7   Tripura                                      Manufacturing   228625.0
# 8   Tripura  Electricity, gas, water supply & other utility...    77870.0
# 9   Tripura                                       Construction   177899.0
# 10  Tripura                                          Secondary   484393.0
# 11  Tripura              Trade, repair, hotels and restaurants   390423.0
# ...

# %%
tri1 = tri.drop(tri.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
tri1 = tri1.drop("State",axis =1)
tri1 = tri1.set_index("Item")
tri1
# Out:
#                                                       2014-15
# Item
# Agriculture, forestry and fishing                    799825.0
# Mining and quarrying                                 142391.0
# Manufacturing                                        228625.0
# Electricity, gas, water supply & other utility ...    77870.0
# Construction                                         177899.0
# Trade, repair, hotels and restaurants                390423.0
# Transport, storage, communication & services re...   155956.0
# Financial services                                    86094.0
# Real estate, ownership of dwelling & profession...   190704.0
# Public administration                                338244.0
# Other services                                       323287.0
# TOTAL GSVA at basic prices                          2911319.0

# %%
c3 = pd.concat([ch1,meg1]).groupby(level=0).sum()
c3
# Out:
#                                                        2014-15
# Item
# Agriculture, forestry and fishing                    4315368.0
# Construction                                         2820111.0
# Electricity, gas, water supply & other utility ...   1252911.0
# Financial services                                    803148.0
# Manufacturing                                        4803806.0
# Mining and quarrying                                 2536499.0
# Other services                                       1326443.0
# Public administration                                1107764.0
# Real estate, ownership of dwelling & profession...   2612575.0
# TOTAL GSVA at basic prices                          24518128.0
# Trade, repair, hotels and restaurants                1919545.0
# Transport, storage, communication & services re...   1019959.0

# %%
c3 = pd.concat([c3,miz1]).groupby(level=0).sum()
c3
# Out:
#                                                        2014-15
# Item
# Agriculture, forestry and fishing                    4532378.0
# Construction                                         2953339.0
# Electricity, gas, water supply & other utility ...   1381276.0
# Financial services                                    826316.0
# Manufacturing                                        4812285.0
# Mining and quarrying                                 2545087.0
# Other services                                       1512665.0
# Public administration                                1314023.0
# Real estate, ownership of dwelling & profession...   2667643.0
# TOTAL GSVA at basic prices                          25651417.0
# Trade, repair, hotels and restaurants                2033860.0
# Transport, storage, communication & services re...   1072546.0

# %%
c3 = pd.concat([c3,nag1]).groupby(level=0).sum()
c3
# Out:
#                                                        2014-15
# Item
# Agriculture, forestry and fishing                    5140275.0
# Construction                                         3109411.0
# Electricity, gas, water supply & other utility ...   1419220.0
# Financial services                                    886709.0
# Manufacturing                                        4830631.0
# Mining and quarrying                                 2553367.0
# Other services                                       1771851.0
# Public administration                                1609447.0
# Real estate, ownership of dwelling & profession...   2827294.0
# TOTAL GSVA at basic prices                          27472912.0
# Trade, repair, hotels and restaurants                2174641.0
# Transport, storage, communication & services re...   1150067.0

# %%
c3 = pd.concat([c3,odi1]).groupby(level=0).sum()
c3
# Out:
#                                                        2014-15
# Item
# Agriculture, forestry and fishing                   11563253.0
# Construction                                         5511807.0
# Electricity, gas, water supply & other utility ...   2252287.0
# Financial services                                   1951856.0
# Manufacturing                                       10584860.0
# Mining and quarrying                                 5139695.0
# Other services                                       4112454.0
# Public administration                                2927668.0
# Real estate, ownership of dwelling & profession...   5176008.0
# TOTAL GSVA at basic prices                          57728168.0
# Trade, repair, hotels and restaurants                5324196.0
# Transport, storage, communication & services re...   3184083.0

# %%
c3 = pd.concat([c3,raj1]).groupby(level=0).sum()
c3
# Out:
#                                                         2014-15
# Item
# Agriculture, forestry and fishing                    26607647.0
# Construction                                         10865133.0
# Electricity, gas, water supply & other utility ...    3375175.0
# Financial services                                    3779269.0
# Manufacturing                                        17137440.0
# Mining and quarrying                                  9209080.0
# Other services                                        8276741.0
# Public administration                                 5388032.0
# Real estate, ownership of dwelling & profession...   11628005.0
# TOTAL GSVA at basic prices                          115886554.0
# Trade, repair, hotels and restaurants                12621486.0
# Transport, storage, communication & services re...    6998544.0

# %%
c3 = pd.concat([c3,tri1]).groupby(level=0).sum()
c3
# Out:
#                                                         2014-15
# Item
# Agriculture, forestry and fishing                    27407472.0
# Construction                                         11043032.0
# Electricity, gas, water supply & other utility ...    3453045.0
# Financial services                                    3865363.0
# Manufacturing                                        17366065.0
# Mining and quarrying                                  9351471.0
# Other services                                        8600028.0
# Public administration                                 5726276.0
# Real estate, ownership of dwelling & profession...   11818709.0
# TOTAL GSVA at basic prices                          118797873.0
# Trade, repair, hotels and restaurants                13011909.0
# Transport, storage, communication & services re...    7154500.0

# %%
c3 = c3.sort_values('2014-15')
c3
# Out:
#                                                         2014-15
# Item
# Electricity, gas, water supply & other utility ...    3453045.0
# Financial services                                    3865363.0
# Public administration                                 5726276.0
# Transport, storage, communication & services re...    7154500.0
# Other services                                        8600028.0
# Mining and quarrying                                  9351471.0
# Construction                                         11043032.0
# Real estate, ownership of dwelling & profession...   11818709.0
# Trade, repair, hotels and restaurants                13011909.0
# Manufacturing                                        17366065.0
# Agriculture, forestry and fishing                    27407472.0
# TOTAL GSVA at basic prices                          118797873.0

# %% [markdown]
# Top Sub-Sector which contribute 80% of the GSDP : Agriculture, forestry and fishing, Manufacturing, Trade, repair, hotels and restaurants, Real estate, ownership of dwelling & professional services, Construction and Mining and quarrying

# %%
c3 = c3.loc[:'Agriculture, forestry and fishing',:]
c3
# Out:
#                                                        2014-15
# Item
# Electricity, gas, water supply & other utility ...   3453045.0
# Financial services                                   3865363.0
# Public administration                                5726276.0
# Transport, storage, communication & services re...   7154500.0
# Other services                                       8600028.0
# Mining and quarrying                                 9351471.0
# Construction                                        11043032.0
# Real estate, ownership of dwelling & profession...  11818709.0
# Trade, repair, hotels and restaurants               13011909.0
# Manufacturing                                       17366065.0
# Agriculture, forestry and fishing                   27407472.0

# %%
plt.figure(figsize= (10,10))
plt.pie(c3['2014-15'], labels = c3.index, autopct='%1.1f%%')
plt.title("Sub-Sector's % contribution of category C3")
plt.show()

# %% [markdown]
# c4 - states : Assam, Bihar, Jharkhand, Madhya Pradesh, Manipur, Uttar Pradesh

# %%
asa
# Out:
#     State                                               Item   2014-15
# 0   Assam                  Agriculture, forestry and fishing   3855548
# 1   Assam                                              Crops   2890544
# 2   Assam                                          Livestock    173478
# 3   Assam                               Forestry and logging    261987
# 4   Assam                            Fishing and aquaculture    529539
# 5   Assam                               Mining and quarrying   1471149
# 6   Assam                                            Primary   5326697
# 7   Assam                                      Manufacturing   2002936
# 8   Assam  Electricity, gas, water supply & other utility...    296587
# 9   Assam                                       Construction   1733568
# 10  Assam                                          Secondary   4033091
# 11  Assam              Trade, repair, hotels and restaurants   2987155
# ...

# %%
asa1 = asa.drop(asa.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
asa1 = asa1.drop("State",axis =1)
asa1 = asa1.set_index("Item")
asa1
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                    3855548
# Mining and quarrying                                 1471149
# Manufacturing                                        2002936
# Electricity, gas, water supply & other utility ...    296587
# Construction                                         1733568
# Trade, repair, hotels and restaurants                2987155
# Transport, storage, communication & services re...   1194568
# Financial services                                    543651
# Real estate, ownership of dwelling & profession...   1412466
# Public administration                                1373611
# Other services                                       1795658
# TOTAL GSVA at basic prices                          18666897

# %%
bi
# Out:
#     State                                               Item   2014-15
# 0   Bihar                  Agriculture, forestry and fishing   7951890
# 1   Bihar                                              Crops   4688237
# 2   Bihar                                          Livestock   2060296
# 3   Bihar                               Forestry and logging    550132
# 4   Bihar                            Fishing and aquaculture    653224
# 5   Bihar                               Mining and quarrying     68107
# 6   Bihar                                            Primary   8019997
# 7   Bihar                                      Manufacturing   2189965
# 8   Bihar  Electricity, gas, water supply & other utility...    345168
# 9   Bihar                                       Construction   3449763
# 10  Bihar                                          Secondary   5984896
# 11  Bihar              Trade, repair, hotels and restaurants   7448373
# ...

# %%
bi1 = bi.drop(bi.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
bi1 = bi1.drop("State",axis =1)
bi1 = bi1.set_index("Item")
bi1
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                    7951890
# Mining and quarrying                                   68107
# Manufacturing                                        2189965
# Electricity, gas, water supply & other utility ...    345168
# Construction                                         3449763
# Trade, repair, hotels and restaurants                7448373
# Transport, storage, communication & services re...   3147173
# Financial services                                   1178022
# Real estate, ownership of dwelling & profession...   3740641
# Public administration                                2078171
# Other services                                       4587589
# TOTAL GSVA at basic prices                          36184863

# %%
jha
# Out:
#         State                                               Item   2014-15
# 0   Jharkhand                  Agriculture, forestry and fishing   3211065
# 1   Jharkhand                                              Crops   2094466
# 2   Jharkhand                                          Livestock    562503
# 3   Jharkhand                               Forestry and logging    445149
# 4   Jharkhand                            Fishing and aquaculture    108947
# 5   Jharkhand                               Mining and quarrying   2037289
# 6   Jharkhand                                            Primary   5248354
# 7   Jharkhand                                      Manufacturing   4114148
# 8   Jharkhand  Electricity, gas, water supply & other utility...    337489
# 9   Jharkhand                                       Construction   1789834
# 10  Jharkhand                                          Secondary   6241471
# ...

# %%
jha1 = jha.drop(jha.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
jha1 = jha1.drop("State",axis =1)
jha1 = jha1.set_index("Item")
jha1
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                    3211065
# Mining and quarrying                                 2037289
# Manufacturing                                        4114148
# Electricity, gas, water supply & other utility ...    337489
# Construction                                         1789834
# Trade, repair, hotels and restaurants                1991359
# Transport, storage, communication & services re...   1470022
# Financial services                                    551441
# Real estate, ownership of dwelling & profession...   1656784
# Public administration                                1088325
# Other services                                       1375410
# TOTAL GSVA at basic prices                          19623166

# %%
mp
# Out:
#              State                                               Item  \
# 0   Madhya_Pradesh                  Agriculture, forestry and fishing
# 1   Madhya_Pradesh                                              Crops
# 2   Madhya_Pradesh                                          Livestock
# 3   Madhya_Pradesh                               Forestry and logging
# 4   Madhya_Pradesh                            Fishing and aquaculture
# 5   Madhya_Pradesh                               Mining and quarrying
# 6   Madhya_Pradesh                                            Primary
# 7   Madhya_Pradesh                                      Manufacturing
# 8   Madhya_Pradesh  Electricity, gas, water supply & other utility...
# 9   Madhya_Pradesh                                       Construction
# 10  Madhya_Pradesh                                          Secondary
# 11  Madhya_Pradesh              Trade, repair, hotels and restaurants
# ...

# %%
mp1 = mp.drop(mp.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
mp1 = mp1.drop("State",axis =1)
mp1 = mp1.set_index("Item")
mp1
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                   16235647
# Mining and quarrying                                 1618373
# Manufacturing                                        4368833
# Electricity, gas, water supply & other utility ...   1272905
# Construction                                         4403151
# Trade, repair, hotels and restaurants                5357515
# Transport, storage, communication & services re...   2865802
# Financial services                                   1988794
# Real estate, ownership of dwelling & profession...   2660123
# Public administration                                2497321
# Other services                                       2747805
# TOTAL GSVA at basic prices                          46016269

# %%
man
# Out:
#       State                                               Item    2014-15
# 0   Manipur                  Agriculture, forestry and fishing   383140.0
# 1   Manipur                                              Crops   226583.0
# 2   Manipur                                          Livestock    75483.0
# 3   Manipur                               Forestry and logging    45831.0
# 4   Manipur                            Fishing and aquaculture    35243.0
# 5   Manipur                               Mining and quarrying        0.0
# 6   Manipur                                            Primary   383140.0
# 7   Manipur                                      Manufacturing    49501.0
# 8   Manipur  Electricity, gas, water supply & other utility...    27490.0
# 9   Manipur                                       Construction   143182.0
# 10  Manipur                                          Secondary   220173.0
# 11  Manipur              Trade, repair, hotels and restaurants   262950.0
# ...

# %%
man1 = man.drop(man.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
man1 = man1.drop("State",axis =1)
man1 = man1.set_index("Item")
man1
# Out:
#                                                       2014-15
# Item
# Agriculture, forestry and fishing                    383140.0
# Mining and quarrying                                      0.0
# Manufacturing                                         49501.0
# Electricity, gas, water supply & other utility ...    27490.0
# Construction                                         143182.0
# Trade, repair, hotels and restaurants                262950.0
# Transport, storage, communication & services re...   109726.0
# Financial services                                    30315.0
# Real estate, ownership of dwelling & profession...   159335.0
# Public administration                                297078.0
# Other services                                       317930.0
# TOTAL GSVA at basic prices                          1780647.0

# %%
up
# Out:
#             State                                               Item  \
# 0   Uttar_Pradesh                  Agriculture, forestry and fishing
# 1   Uttar_Pradesh                                              Crops
# 2   Uttar_Pradesh                                          Livestock
# 3   Uttar_Pradesh                               Forestry and logging
# 4   Uttar_Pradesh                            Fishing and aquaculture
# 5   Uttar_Pradesh                               Mining and quarrying
# 6   Uttar_Pradesh                                            Primary
# 7   Uttar_Pradesh                                      Manufacturing
# 8   Uttar_Pradesh  Electricity, gas, water supply & other utility...
# 9   Uttar_Pradesh                                       Construction
# 10  Uttar_Pradesh                                          Secondary
# 11  Uttar_Pradesh              Trade, repair, hotels and restaurants
# 12  Uttar_Pradesh                            Trade & repair services
# ...

# %%
#Dropping the unecessary rows and dropping the state column and changing the Index column to item column
up1 = up.drop(up.index[[1,2,3,4,6,10,12,13,15,16,17,18,19,20,21,26,28,29,30,31,32]])
up1 = up1.drop("State",axis =1)
up1 = up1.set_index("Item")
up1
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                   25097754
# Mining and quarrying                                  901501
# Manufacturing                                       12261649
# Electricity, gas, water supply & other utility ...   2030625
# Construction                                        11256450
# Trade, repair, hotels and restaurants                9437243
# Transport, storage, communication & services re...   7404509
# Financial services                                   3392275
# Real estate, ownership of dwelling & profession...  14548185
# Public administration                                6152124
# Other services                                       5034623
# TOTAL GSVA at basic prices                          97516938

# %%
#Concatinating and adding the values of dataframe
c4 = pd.concat([asa1,bi1]).groupby(level=0).sum()
c4
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                   11807438
# Construction                                         5183331
# Electricity, gas, water supply & other utility ...    641755
# Financial services                                   1721673
# Manufacturing                                        4192901
# Mining and quarrying                                 1539256
# Other services                                       6383247
# Public administration                                3451782
# Real estate, ownership of dwelling & profession...   5153107
# TOTAL GSVA at basic prices                          54851760
# Trade, repair, hotels and restaurants               10435528
# Transport, storage, communication & services re...   4341741

# %%
c4 = pd.concat([c4,jha1]).groupby(level=0).sum()
c4
# Out:
#                                                      2014-15
# Item
# Agriculture, forestry and fishing                   15018503
# Construction                                         6973165
# Electricity, gas, water supply & other utility ...    979244
# Financial services                                   2273114
# Manufacturing                                        8307049
# Mining and quarrying                                 3576545
# Other services                                       7758657
# Public administration                                4540107
# Real estate, ownership of dwelling & profession...   6809891
# TOTAL GSVA at basic prices                          74474926
# Trade, repair, hotels and restaurants               12426887
# Transport, storage, communication & services re...   5811763

# %%
c4 = pd.concat([c4,mp1]).groupby(level=0).sum()
c4
# Out:
#                                                       2014-15
# Item
# Agriculture, forestry and fishing                    31254150
# Construction                                         11376316
# Electricity, gas, water supply & other utility ...    2252149
# Financial services                                    4261908
# Manufacturing                                        12675882
# Mining and quarrying                                  5194918
# Other services                                       10506462
# Public administration                                 7037428
# Real estate, ownership of dwelling & profession...    9470014
# TOTAL GSVA at basic prices                          120491195
# Trade, repair, hotels and restaurants                17784402
# Transport, storage, communication & services re...    8677565

# %%
c4 = pd.concat([c4,man1]).groupby(level=0).sum()
c4
# Out:
#                                                         2014-15
# Item
# Agriculture, forestry and fishing                    31637290.0
# Construction                                         11519498.0
# Electricity, gas, water supply & other utility ...    2279639.0
# Financial services                                    4292223.0
# Manufacturing                                        12725383.0
# Mining and quarrying                                  5194918.0
# Other services                                       10824392.0
# Public administration                                 7334506.0
# Real estate, ownership of dwelling & profession...    9629349.0
# TOTAL GSVA at basic prices                          122271842.0
# Trade, repair, hotels and restaurants                18047352.0
# Transport, storage, communication & services re...    8787291.0

# %%
#Concatinating and adding the dataframes
c4 = pd.concat([c4,up1]).groupby(level=0).sum()
c4
# Out:
#                                                         2014-15
# Item
# Agriculture, forestry and fishing                    56735044.0
# Construction                                         22775948.0
# Electricity, gas, water supply & other utility ...    4310264.0
# Financial services                                    7684498.0
# Manufacturing                                        24987032.0
# Mining and quarrying                                  6096419.0
# Other services                                       15859015.0
# Public administration                                13486630.0
# Real estate, ownership of dwelling & profession...   24177534.0
# TOTAL GSVA at basic prices                          219788780.0
# Trade, repair, hotels and restaurants                27484595.0
# Transport, storage, communication & services re...   16191800.0

# %%
#Sorting the dataframe
c4 = c4.sort_values('2014-15')
c4
# Out:
#                                                         2014-15
# Item
# Electricity, gas, water supply & other utility ...    4310264.0
# Mining and quarrying                                  6096419.0
# Financial services                                    7684498.0
# Public administration                                13486630.0
# Other services                                       15859015.0
# Transport, storage, communication & services re...   16191800.0
# Construction                                         22775948.0
# Real estate, ownership of dwelling & profession...   24177534.0
# Manufacturing                                        24987032.0
# Trade, repair, hotels and restaurants                27484595.0
# Agriculture, forestry and fishing                    56735044.0
# TOTAL GSVA at basic prices                          219788780.0

# %% [markdown]
# Top Sub-Sector which contribute 80% of the GSDP : Agriculture, forestry and fishing, Trade, repair, hotels and restaurants, Manufacturing, Real estate, ownership of dwelling & professional services, Construction, Transport, storage, communication & services related to broadcasting

# %%
#Removing the row TOTAL GSVA
c4 = c4.loc[:'Agriculture, forestry and fishing',:]
c4
# Out:
#                                                        2014-15
# Item
# Electricity, gas, water supply & other utility ...   4310264.0
# Mining and quarrying                                 6096419.0
# Financial services                                   7684498.0
# Public administration                               13486630.0
# Other services                                      15859015.0
# Transport, storage, communication & services re...  16191800.0
# Construction                                        22775948.0
# Real estate, ownership of dwelling & profession...  24177534.0
# Manufacturing                                       24987032.0
# Trade, repair, hotels and restaurants               27484595.0
# Agriculture, forestry and fishing                   56735044.0

# %%
#Plotting the pie chart
plt.figure(figsize= (10,10))
plt.pie(c4['2014-15'], labels = c4.index, autopct='%1.1f%%')
plt.title("Sub-Sector's % contribution of category C4")
plt.show()

# %% [markdown]
# # Part 2

# %%
#Reading the csv file
dropout = pd.read_csv(r"H:\UpGrad\Statistics & EDA\GDP Analysis\drop out rate data.csv")
dropout
# Out:
#       Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0           1              A & N Islands                 0.68
# 1           2             Andhra Pradesh                 3.18
# 2           3          Arunachal Pradesh                15.16
# 3           4                      Assam                 6.24
# 4           5                      Bihar                  NaN
# 5           6                 Chandigarh                  NaN
# 6           7                Chhatisgarh                 4.14
# 7           8       Dadra & Nagar Haveli                  NaN
# 8           9                Daman & Diu                  NaN
# 9          10                      Delhi                  NaN
# 10         11                        Goa                  NaN
# 11         12                    Gujarat                 0.74
# 12         13                    Haryana                 1.29
# 13         14           Himachal Pradesh                 0.45
# ...

# %%
# Taking the 2014-15 column only
rate = dropout.loc[:,['Level of Education - State','Primary - 2014-2015.1','Upper Primary - 2014-2015','Secondary - 2014-2015']]
rate
# Out:
#    Level of Education - State  Primary - 2014-2015.1  \
# 0               A & N Islands                   0.51
# 1              Andhra Pradesh                   6.72
# 2           Arunachal Pradesh                  10.82
# 3                       Assam                  15.36
# 4                       Bihar                    NaN
# 5                  Chandigarh                    NaN
# 6                 Chhatisgarh                   2.91
# 7        Dadra & Nagar Haveli                   1.47
# 8                 Daman & Diu                   1.11
# 9                       Delhi                    NaN
# 10                        Goa                   0.73
# 11                    Gujarat                   0.89
# 12                    Haryana                   5.61
# 13           Himachal Pradesh                   0.64
# 14          Jammu and Kashmir                   6.79
# 15                  Jharkhand                   5.48
# 16                  Karnataka                   2.02
# ...

# %%
# Dropping the states row which are Union Teritory and which are not in the gsdp dataframe
rate = rate.drop(rate.index[[0,5,7,8,9,14,18,26,35,36]])
rate
# Out:
#    Level of Education - State  Primary - 2014-2015.1  \
# 1              Andhra Pradesh                   6.72
# 2           Arunachal Pradesh                  10.82
# 3                       Assam                  15.36
# 4                       Bihar                    NaN
# 6                 Chhatisgarh                   2.91
# 10                        Goa                   0.73
# 11                    Gujarat                   0.89
# 12                    Haryana                   5.61
# 13           Himachal Pradesh                   0.64
# 15                  Jharkhand                   5.48
# 16                  Karnataka                   2.02
# 17                     Kerala                    NaN
# 19             Madhya Pradesh                   6.59
# 20                Maharashtra                   1.26
# 21                    Manipur                   9.66
# 22                  Meghalaya                   9.46
# 23                    Mizoram                  10.10
# ...

# %%
# changing the index column to Level of Education - State
rate = rate.set_index('Level of Education - State')
rate
# Out:
#                             Primary - 2014-2015.1  Upper Primary - 2014-2015  \
# Level of Education - State
# Andhra Pradesh                               6.72                       5.20
# Arunachal Pradesh                           10.82                       6.71
# Assam                                       15.36                      10.51
# Bihar                                         NaN                       4.08
# Chhatisgarh                                  2.91                       5.85
# Goa                                          0.73                       0.07
# Gujarat                                      0.89                       6.41
# Haryana                                      5.61                       5.81
# Himachal Pradesh                             0.64                       0.87
# Jharkhand                                    5.48                       8.99
# Karnataka                                    2.02                       3.85
# ...

# %%
#Replacing the null values in the dataframe with the average value of their respective column
rate.loc[np.isnan(rate['Primary - 2014-2015.1']),['Primary - 2014-2015.1']] = rate['Primary - 2014-2015.1'].mean()
rate.loc[np.isnan(rate['Upper Primary - 2014-2015']),['Upper Primary - 2014-2015']] = rate['Upper Primary - 2014-2015'].mean()
rate
# Out:
#                             Primary - 2014-2015.1  Upper Primary - 2014-2015  \
# Level of Education - State
# Andhra Pradesh                           6.720000                     5.2000
# Arunachal Pradesh                       10.820000                     6.7100
# Assam                                   15.360000                    10.5100
# Bihar                                    5.126667                     4.0800
# Chhatisgarh                              2.910000                     5.8500
# Goa                                      0.730000                     0.0700
# Gujarat                                  0.890000                     6.4100
# Haryana                                  5.610000                     5.8100
# Himachal Pradesh                         0.640000                     0.8700
# Jharkhand                                5.480000                     8.9900
# Karnataka                                2.020000                     3.8500
# ...

# %%
#Displaying the gsdp Dataframe
gsdp
# Out:
#                                     Item   2014-15
# State
# Andhra_Pradesh     Per Capita GSDP (Rs.)  104977.0
# Arunachal_Pradesh  Per Capita GSDP (Rs.)  112718.0
# Assam              Per Capita GSDP (Rs.)   60621.0
# Bihar              Per Capita GSDP (Rs.)   33954.0
# Chattisgarh        Per Capita GSDP (Rs.)   86860.0
# Goa                Per Capita GSDP (Rs.)  271793.0
# Gujrat             Per Capita GSDP (Rs.)  141263.0
# Haryana            Per Capita GSDP (Rs.)  164077.0
# Himachal_Pradesh   Per Capita GSDP (Rs.)  147330.0
# Jharkhand          Per Capita GSDP (Rs.)   62091.0
# Karnataka          Per Capita GSDP (Rs.)  145141.0
# Kerala             Per Capita GSDP (Rs.)  154778.0
# Madhya_Pradesh     Per Capita GSDP (Rs.)   62989.0
# Maharashtra        Per Capita GSDP (Rs.)  152853.0
# Manipur            Per Capita GSDP (Rs.)   58442.0
# Meghalaya          Per Capita GSDP (Rs.)   76228.0
# Mizoram            Per Capita GSDP (Rs.)   97687.0
# ...

# %%
#Sorting the gsdp dataframe alphabatically according to state
gsdp = gsdp.sort_values('State')

# %%
#Desplaying the gsdp datframe
gsdp
# Out:
#                                     Item   2014-15
# State
# Andhra_Pradesh     Per Capita GSDP (Rs.)  104977.0
# Arunachal_Pradesh  Per Capita GSDP (Rs.)  112718.0
# Assam              Per Capita GSDP (Rs.)   60621.0
# Bihar              Per Capita GSDP (Rs.)   33954.0
# Chattisgarh        Per Capita GSDP (Rs.)   86860.0
# Goa                Per Capita GSDP (Rs.)  271793.0
# Gujrat             Per Capita GSDP (Rs.)  141263.0
# Haryana            Per Capita GSDP (Rs.)  164077.0
# Himachal_Pradesh   Per Capita GSDP (Rs.)  147330.0
# Jharkhand          Per Capita GSDP (Rs.)   62091.0
# Karnataka          Per Capita GSDP (Rs.)  145141.0
# Kerala             Per Capita GSDP (Rs.)  154778.0
# Madhya_Pradesh     Per Capita GSDP (Rs.)   62989.0
# Maharashtra        Per Capita GSDP (Rs.)  152853.0
# Manipur            Per Capita GSDP (Rs.)   58442.0
# Meghalaya          Per Capita GSDP (Rs.)   76228.0
# Mizoram            Per Capita GSDP (Rs.)   97687.0
# ...

# %%
#Desplaying the rate dataframe
rate
# Out:
#                             Primary - 2014-2015.1  Upper Primary - 2014-2015  \
# Level of Education - State
# Andhra Pradesh                           6.720000                     5.2000
# Arunachal Pradesh                       10.820000                     6.7100
# Assam                                   15.360000                    10.5100
# Bihar                                    5.126667                     4.0800
# Chhatisgarh                              2.910000                     5.8500
# Goa                                      0.730000                     0.0700
# Gujarat                                  0.890000                     6.4100
# Haryana                                  5.610000                     5.8100
# Himachal Pradesh                         0.640000                     0.8700
# Jharkhand                                5.480000                     8.9900
# Karnataka                                2.020000                     3.8500
# ...

# %%
#Rename the index of the rate dataframe to match the gsdp dataframe
rate.rename(index={'Andhra Pradesh':'Andhra_Pradesh','Arunachal Pradesh': 'Arunachal_Pradesh','Chhatisgarh':'Chattisgarh','Gujarat':'Gujrat','Himachal Pradesh':'Himachal_Pradesh','Madhya Pradesh':'Madhya_Pradesh','Odisha':'Orissa','Tamil Nadu':'Tamil_Nadu','Uttar Pradesh':'Uttar_Pradesh','Uttrakhand':'Uttarakhand'},inplace =True)

# %%
#Desplaying the rate dataframe
rate
# Out:
#                             Primary - 2014-2015.1  Upper Primary - 2014-2015  \
# Level of Education - State
# Andhra_Pradesh                           6.720000                     5.2000
# Arunachal_Pradesh                       10.820000                     6.7100
# Assam                                   15.360000                    10.5100
# Bihar                                    5.126667                     4.0800
# Chattisgarh                              2.910000                     5.8500
# Goa                                      0.730000                     0.0700
# Gujrat                                   0.890000                     6.4100
# Haryana                                  5.610000                     5.8100
# Himachal_Pradesh                         0.640000                     0.8700
# Jharkhand                                5.480000                     8.9900
# Karnataka                                2.020000                     3.8500
# ...

# %%
#Renaming the column of the gsdp dataframe
gsdp.rename(columns={'2014-15': 'PerCaita GSDP'},inplace = True)         
gsdp
# Out:
#                                     Item  PerCaita GSDP
# State
# Andhra_Pradesh     Per Capita GSDP (Rs.)       104977.0
# Arunachal_Pradesh  Per Capita GSDP (Rs.)       112718.0
# Assam              Per Capita GSDP (Rs.)        60621.0
# Bihar              Per Capita GSDP (Rs.)        33954.0
# Chattisgarh        Per Capita GSDP (Rs.)        86860.0
# Goa                Per Capita GSDP (Rs.)       271793.0
# Gujrat             Per Capita GSDP (Rs.)       141263.0
# Haryana            Per Capita GSDP (Rs.)       164077.0
# Himachal_Pradesh   Per Capita GSDP (Rs.)       147330.0
# Jharkhand          Per Capita GSDP (Rs.)        62091.0
# Karnataka          Per Capita GSDP (Rs.)       145141.0
# Kerala             Per Capita GSDP (Rs.)       154778.0
# Madhya_Pradesh     Per Capita GSDP (Rs.)        62989.0
# Maharashtra        Per Capita GSDP (Rs.)       152853.0
# Manipur            Per Capita GSDP (Rs.)        58442.0
# Meghalaya          Per Capita GSDP (Rs.)        76228.0
# ...

# %%
#Renamimg the column of the rate dataframe
rate.rename(columns={'Primary - 2014-2015.1': 'Primary','Upper Primary - 2014-2015':'Upper Primary','Secondary - 2014-2015':'Secondary'}, inplace=True)
rate
# Out:
#                               Primary  Upper Primary  Secondary
# Level of Education - State
# Andhra_Pradesh               6.720000         5.2000      15.71
# Arunachal_Pradesh           10.820000         6.7100      17.11
# Assam                       15.360000        10.5100      27.06
# Bihar                        5.126667         4.0800      25.90
# Chattisgarh                  2.910000         5.8500      21.26
# Goa                          0.730000         0.0700      11.15
# Gujrat                       0.890000         6.4100      25.04
# Haryana                      5.610000         5.8100      15.89
# Himachal_Pradesh             0.640000         0.8700       6.07
# Jharkhand                    5.480000         8.9900      24.00
# Karnataka                    2.020000         3.8500      26.18
# Kerala                       5.126667         4.5044      12.32
# Madhya_Pradesh               6.590000         9.2000      24.77
# ...

# %%
#Merging the gsdp and rate dataframe together side-by-side
dor = pd.concat([gsdp,rate],axis=1)
dor
# Out:
#                                     Item  PerCaita GSDP    Primary  \
# Andhra_Pradesh     Per Capita GSDP (Rs.)       104977.0   6.720000
# Arunachal_Pradesh  Per Capita GSDP (Rs.)       112718.0  10.820000
# Assam              Per Capita GSDP (Rs.)        60621.0  15.360000
# Bihar              Per Capita GSDP (Rs.)        33954.0   5.126667
# Chattisgarh        Per Capita GSDP (Rs.)        86860.0   2.910000
# Goa                Per Capita GSDP (Rs.)       271793.0   0.730000
# Gujrat             Per Capita GSDP (Rs.)       141263.0   0.890000
# Haryana            Per Capita GSDP (Rs.)       164077.0   5.610000
# Himachal_Pradesh   Per Capita GSDP (Rs.)       147330.0   0.640000
# Jharkhand          Per Capita GSDP (Rs.)        62091.0   5.480000
# Karnataka          Per Capita GSDP (Rs.)       145141.0   2.020000
# Kerala             Per Capita GSDP (Rs.)       154778.0   5.126667
# Madhya_Pradesh     Per Capita GSDP (Rs.)        62989.0   6.590000
# ...

# %%
#Removing the column Item
dor = dor.drop('Item',axis =1)
dor
# Out:
#                    PerCaita GSDP    Primary  Upper Primary  Secondary
# Andhra_Pradesh          104977.0   6.720000         5.2000      15.71
# Arunachal_Pradesh       112718.0  10.820000         6.7100      17.11
# Assam                    60621.0  15.360000        10.5100      27.06
# Bihar                    33954.0   5.126667         4.0800      25.90
# Chattisgarh              86860.0   2.910000         5.8500      21.26
# Goa                     271793.0   0.730000         0.0700      11.15
# Gujrat                  141263.0   0.890000         6.4100      25.04
# Haryana                 164077.0   5.610000         5.8100      15.89
# Himachal_Pradesh        147330.0   0.640000         0.8700       6.07
# Jharkhand                62091.0   5.480000         8.9900      24.00
# Karnataka               145141.0   2.020000         3.8500      26.18
# Kerala                  154778.0   5.126667         4.5044      12.32
# ...

# %%
#plotting 'PerCapita GSDP vs Primary Dropout Rate'
sns.jointplot('PerCaita GSDP','Primary', dor, color = 'r' )
plt.show()

# %%
#plotting 'PerCapita GSDP vs Upper Primary Dropout Rate'
sns.jointplot('PerCaita GSDP','Upper Primary', dor, color = 'b' )
plt.show()

# %%
#plotting 'PerCapita GSDP vs Secondary Dropout Rate'
sns.jointplot('PerCaita GSDP','Secondary', dor, color = 'g' )
plt.show()
